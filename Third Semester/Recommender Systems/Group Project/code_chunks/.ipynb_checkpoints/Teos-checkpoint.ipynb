# %%
# !pip install nltk
# !pip install langchain
# !pip install sentence_transformers
# !pip install openai
# !pip install tiktoken
# Out:
# Collecting nltk
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk) (8.1.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk) (4.64.1)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk) (2022.10.31)
# Installing collected packages: nltk
# Successfully installed nltk-3.8.1
# Collecting langchain
#   Using cached langchain-0.0.228-py3-none-any.whl (1.3 MB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/conda/lib/python3.10/site-packages (from langchain) (3.8.4)
# Collecting langchainplus-sdk<0.0.21,>=0.0.20
#   Using cached langchainplus_sdk-0.0.20-py3-none-any.whl (25 kB)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /opt/conda/lib/python3.10/site-packages (from langchain) (8.2.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/conda/lib/python3.10/site-packages (from langchain) (2.0.1)
# Collecting pydantic<2,>=1
#   Using cached pydantic-1.10.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Collecting dataclasses-json<0.6.0,>=0.5.7
#   Using cached dataclasses_json-0.5.9-py3-none-any.whl (26 kB)
# Requirement already satisfied: numpy<2,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain) (1.23.5)
# Collecting openapi-schema-pydantic<2.0,>=1.2
#   Using cached openapi_schema_pydantic-1.2.4-py3-none-any.whl (90 kB)
# Requirement already satisfied: PyYAML>=5.4.1 in /opt/conda/lib/python3.10/site-packages (from langchain) (6.0)
# Requirement already satisfied: requests<3,>=2 in /opt/conda/lib/python3.10/site-packages (from langchain) (2.28.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from langchain) (4.0.2)
# Collecting numexpr<3.0.0,>=2.8.4
#   Using cached numexpr-2.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (381 kB)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (22.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.1.1)
# Collecting typing-inspect>=0.4.0
#   Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting marshmallow<4.0.0,>=3.3.0
#   Using cached marshmallow-3.19.0-py3-none-any.whl (49 kB)
# Collecting marshmallow-enum<2.0.0,>=1.5.1
#   Using cached marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<2,>=1->langchain) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.2)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (23.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from typing-inspect>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (1.0.0)
# Installing collected packages: typing-inspect, pydantic, numexpr, marshmallow, openapi-schema-pydantic, marshmallow-enum, langchainplus-sdk, dataclasses-json, langchain
#   Attempting uninstall: numexpr
#     Found existing installation: numexpr 2.8.3
#     Uninstalling numexpr-2.8.3:
#       Successfully uninstalled numexpr-2.8.3
# Successfully installed dataclasses-json-0.5.9 langchain-0.0.228 langchainplus-sdk-0.0.20 marshmallow-3.19.0 marshmallow-enum-1.5.1 numexpr-2.8.4 openapi-schema-pydantic-1.2.4 pydantic-1.10.11 typing-inspect-0.9.0
# Collecting sentence_transformers
#   Using cached sentence_transformers-2.2.2-py3-none-any.whl
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (1.23.5)
# Collecting huggingface-hub>=0.4.0
#   Using cached huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
# Collecting sentencepiece
#   Using cached sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Collecting torch>=1.6.0
#   Using cached torch-2.0.1-cp310-cp310-manylinux1_x86_64.whl (619.9 MB)
# Collecting transformers<5.0.0,>=4.6.0
#   Using cached transformers-4.30.2-py3-none-any.whl (7.2 MB)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (3.8.1)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (1.10.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (4.64.1)
# Collecting torchvision
#   Using cached torchvision-0.15.2-cp310-cp310-manylinux1_x86_64.whl (6.0 MB)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.28.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.4.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.0)
# Collecting filelock
#   Using cached filelock-3.12.2-py3-none-any.whl (10 kB)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Using cached nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
# Collecting nvidia-cusolver-cu11==11.4.0.1
#   Using cached nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
# Collecting triton==2.0.0
#   Using cached triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (1.11.1)
# Collecting nvidia-cuda-cupti-cu11==11.7.101
#   Using cached nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Using cached nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
# Collecting nvidia-nvtx-cu11==11.7.91
#   Using cached nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Collecting nvidia-curand-cu11==10.2.10.91
#   Using cached nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (3.0)
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Using cached nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
# Collecting nvidia-nccl-cu11==2.14.3
#   Using cached nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
# Collecting nvidia-cufft-cu11==10.9.0.58
#   Using cached nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
# Collecting nvidia-cusparse-cu11==11.7.4.91
#   Using cached nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Using cached nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->sentence_transformers) (67.1.0)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->sentence_transformers) (0.38.4)
# Collecting lit
#   Using cached lit-16.0.6-py3-none-any.whl
# Collecting cmake
#   Using cached cmake-3.26.4-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (24.0 MB)
# Collecting safetensors>=0.3.1
#   Using cached safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Using cached tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk->sentence_transformers) (8.1.3)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk->sentence_transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision->sentence_transformers) (9.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)
# Installing collected packages: tokenizers, sentencepiece, safetensors, lit, cmake, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, filelock, nvidia-cusolver-cu11, nvidia-cudnn-cu11, huggingface-hub, transformers, triton, torch, torchvision, sentence_transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 2.1.1
#     Uninstalling transformers-2.1.1:
#       Successfully uninstalled transformers-2.1.1
# Successfully installed cmake-3.26.4 filelock-3.12.2 huggingface-hub-0.16.4 lit-16.0.6 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 safetensors-0.3.1 sentence_transformers-2.2.2 sentencepiece-0.1.99 tokenizers-0.13.3 torch-2.0.1 torchvision-0.15.2 transformers-4.30.2 triton-2.0.0
# Collecting openai
#   Using cached openai-0.27.8-py3-none-any.whl (73 kB)
# Requirement already satisfied: requests>=2.20 in /opt/conda/lib/python3.10/site-packages (from openai) (2.28.2)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from openai) (3.8.4)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from openai) (4.64.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20->openai) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20->openai) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20->openai) (1.26.14)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai) (22.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai) (4.0.2)
# Installing collected packages: openai
# Successfully installed openai-0.27.8
# Collecting tiktoken
#   Using cached tiktoken-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
# Requirement already satisfied: requests>=2.26.0 in /opt/conda/lib/python3.10/site-packages (from tiktoken) (2.28.2)
# Requirement already satisfied: regex>=2022.1.18 in /opt/conda/lib/python3.10/site-packages (from tiktoken) (2022.10.31)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (3.4)
# Installing collected packages: tiktoken
# Successfully installed tiktoken-0.4.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk 
import nltk as nlp
nltk.download('stopwords')
import re
from sklearn.feature_extraction.text import TfidfVectorizer
import pickle
from nltk.corpus import stopwords
import json
import openai
openai.api_key = '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'
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/e12141198/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop = set(stopwords.words("german"))

# %%
df = pd.read_csv("../data/articles_2015.csv")

comb = pd.read_csv("combined.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 df = pd.read_csv("../data/articles_2015.csv")
# ----> 3 comb = pd.read_csv("combined.csv")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'combined.csv'

# %% [markdown]
# ## Data Selection and Dataframe merge

# %%
df.shape
# Out:
# (5916, 21)

# %%
df.columns
# Out:
# Index(['article_id', 'date', 'post_img', 'dachzeile', 'issuenr', 'title',
#        'paragraphs', 'characters', 'rubrik', 'ressort', 'subtitle', 'authors',
#        'link', 'freestory_since', 'freestory_until', 'freestory',
#        'freestory_user', 'images', 'ads', 'picture_url', 'picture_credit'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# article_id            0
# date                  0
# post_img           5914
# dachzeile          2815
# issuenr               0
# title                 0
# paragraphs            0
# characters            0
# rubrik             4287
# ressort              78
# subtitle           3663
# authors               0
# link                  0
# freestory_since    5905
# freestory_until    5905
# freestory          5898
# freestory_user     5908
# images             5516
# ads                5916
# picture_url        5916
# picture_credit     5916
# dtype: int64

# %%
df.authors[df.authors == "[]"].count()
# Out:
# 2033

# %%
df.ressort.unique()
# Out:
# array(['Steiermark', 'Falters Zoo', 'Stadtleben', 'Lexikon', 'Politik',
#        'Medien', 'Falter & Meinung', 'Feuilleton', 'Kolumnen', nan,
#        'Aus Wissenschaft und Forschung', 'Titel',
#        'Innovation in der Wissenschaft', 'Wissenschaft und Sprache',
#        'Erforschung von Menschen', 'ESSEN TRINKEN', 'Woche', 'Partytimer',
#        'POLITIK', 'Musik', 'STEIERMARK'], dtype=object)

# %%
newdf = df[["article_id", "title", "paragraphs", "ressort", "authors"]]

# %%
newdf.shape
# Out:
# (5916, 5)

# %%
newdf
# Out:
#                      article_id  \
# 0     FALTER_201512234F1D30CEA9
# 1     FALTER_2015122382119EA87A
# 2     FALTER_2015122317D031535C
# 3     FALTER_20151223D853291AAA
# 4     FALTER_201512238A0DEB6E2D
# ...                         ...
# 5911  FALTER_20150114D1B1464B21
# 5912  FALTER_20150114100173AA99
# 5913  FALTER_201501144F8F9DDBEE
# 5914  FALTER_201501143FF6C01FA5
# 5915  FALTER_20150114D27133E690
#
#                                                   title  \
# 0                    "Bewundere Frau Merkel über alles"
# 1                                           Wildbretter
# 2     Warum es ganz normal sein kann, zwei Zuhause z...
# 3                                      Der Lerchenfisch
# 4                      Uhudler-Orbán und Kernölamazonen
# ...                                                 ...
# 5911             Achte Ausgabe des Festivals in between
# 5912             Punkrock der Marke "Ned deppert sein!"
# 5913  Mit einem Flüchtling in der WG: Neue Initiativ...
# 5914                          Büchersonntag in Hietzing
# 5915  Neuer Floor, neue Party: ein guter Start ins P...
#
#                                              paragraphs      ressort  \
# 0     ['Kinderwagen drängen sich bei der Eingangstür...   Steiermark
# 1     ['Das Handbuch der Kolumnenschreiberei sieht v...  Falters Zoo
# 2     ['Xenia, Fotografin, 22', 'Ich habe bis vor zw...   Stadtleben
# 3     ['Zuerst Korrektur eines Irrtums: Nicht die AM...   Stadtleben
# 4     ['Wann feiert ein Kabarettist eigentlich Silve...      Lexikon
# ...                                                 ...          ...
# 5911  ['Das Konzept ist so einfach wie schlüssig: Zu...      Lexikon
# 5912  ['Drei Songs in viereinhalb Minuten: Lime Crus...      Lexikon
# 5913  ['Warum müssen Menschen, die vor Krieg und Ele...      Politik
# 5914  ['Sammler sind Getriebene, das gilt auch für B...      Lexikon
# 5915  ['Die Kickdrum zischt und dampft, die Snares r...      Lexikon
#
#                                                 authors
# 0                       ['INTERVIEW: GERLINDE PÖLSLER']
# 1                                                    []
# 2                           ['RECHERCHE: BARBARA TÓTH']
# 3                       ['LOKALKRITIK: FLORIAN HOLZER']
# 4     ['SILVESTEREXPERTISE: STEFANIE PANZENBÖCK UND ...
# ...                                                 ...
# 5911                                             ['GS']
# 5912                                                 []
# 5913                         ['BENEDIKT NARODOSLAWSKY']
# 5914                                                 []
# 5915                              ['Katharina Seidler']
#
# [5916 rows x 5 columns]

# %%
comb = comb.rename(columns={"target_article": "article_id", "article_id":"compared_article"})

# %%
comb
# Out:
#                      article_id           compared_article  Similarity
# 0     FALTER_20151223BA00BC1175  FALTER_20150916BCE86F6EB1       0.500
# 1     FALTER_20151223BA00BC1175  FALTER_20150819A2A890F9AE       0.500
# 2     FALTER_20151223BA00BC1175  FALTER_201510077C06FD872C       0.333
# 3     FALTER_20151223BA00BC1175  FALTER_201508261C4D7250DD       0.250
# 4     FALTER_20151223BA00BC1175  FALTER_2015100713F9AA76C4       0.250
# ...                         ...                        ...         ...
# 2950  FALTER_20150422905D6480EE  FALTER_2015081937D3B65442      -0.167
# 2951  FALTER_20150422905D6480EE  FALTER_20150311C1B7224D95      -0.167
# 2952  FALTER_20150422905D6480EE  FALTER_20150429985B51A564      -0.208
# 2953  FALTER_20150422905D6480EE  FALTER_20150401E488A17F61      -0.208
# 2954  FALTER_20150422905D6480EE  FALTER_2015081922D259E1E5      -0.375
#
# [2955 rows x 3 columns]

# %%
merged = newdf.merge(right=comb, how="left", on="article_id")

# %%
comb.article_id.nunique()
# Out:
# 197

# %%
merged[merged.article_id == "FALTER_20151223BA00BC1175"]
# Out:
#                    article_id                  title  \
# 42  FALTER_20151223BA00BC1175  DIE BLACK STREET BOYS
# 43  FALTER_20151223BA00BC1175  DIE BLACK STREET BOYS
# 44  FALTER_20151223BA00BC1175  DIE BLACK STREET BOYS
# 45  FALTER_20151223BA00BC1175  DIE BLACK STREET BOYS
# 46  FALTER_20151223BA00BC1175  DIE BLACK STREET BOYS
# 47  FALTER_20151223BA00BC1175  DIE BLACK STREET BOYS
# 48  FALTER_20151223BA00BC1175  DIE BLACK STREET BOYS
# 49  FALTER_20151223BA00BC1175  DIE BLACK STREET BOYS
# 50  FALTER_20151223BA00BC1175  DIE BLACK STREET BOYS
# 51  FALTER_20151223BA00BC1175  DIE BLACK STREET BOYS
# 52  FALTER_20151223BA00BC1175  DIE BLACK STREET BOYS
# 53  FALTER_20151223BA00BC1175  DIE BLACK STREET BOYS
# 54  FALTER_20151223BA00BC1175  DIE BLACK STREET BOYS
# 55  FALTER_20151223BA00BC1175  DIE BLACK STREET BOYS
# 56  FALTER_20151223BA00BC1175  DIE BLACK STREET BOYS
#
#                                            paragraphs  ressort  \
# 42  ['Harald Mahrer: Der Nachdenkliche', 'Der Älte...  Politik
# 43  ['Harald Mahrer: Der Nachdenkliche', 'Der Älte...  Politik
# 44  ['Harald Mahrer: Der Nachdenkliche', 'Der Älte...  Politik
# 45  ['Harald Mahrer: Der Nachdenkliche', 'Der Älte...  Politik
# 46  ['Harald Mahrer: Der Nachdenkliche', 'Der Älte...  Politik
# 47  ['Harald Mahrer: Der Nachdenkliche', 'Der Älte...  Politik
# 48  ['Harald Mahrer: Der Nachdenkliche', 'Der Älte...  Politik
# 49  ['Harald Mahrer: Der Nachdenkliche', 'Der Älte...  Politik
# 50  ['Harald Mahrer: Der Nachdenkliche', 'Der Älte...  Politik
# 51  ['Harald Mahrer: Der Nachdenkliche', 'Der Älte...  Politik
# 52  ['Harald Mahrer: Der Nachdenkliche', 'Der Älte...  Politik
# 53  ['Harald Mahrer: Der Nachdenkliche', 'Der Älte...  Politik
# 54  ['Harald Mahrer: Der Nachdenkliche', 'Der Älte...  Politik
# 55  ['Harald Mahrer: Der Nachdenkliche', 'Der Älte...  Politik
# 56  ['Harald Mahrer: Der Nachdenkliche', 'Der Älte...  Politik
#
#                                               authors  \
# 42  ['Politische Stilkritik: Josef Redl und Barbar...
# 43  ['Politische Stilkritik: Josef Redl und Barbar...
# 44  ['Politische Stilkritik: Josef Redl und Barbar...
# 45  ['Politische Stilkritik: Josef Redl und Barbar...
# 46  ['Politische Stilkritik: Josef Redl und Barbar...
# 47  ['Politische Stilkritik: Josef Redl und Barbar...
# 48  ['Politische Stilkritik: Josef Redl und Barbar...
# 49  ['Politische Stilkritik: Josef Redl und Barbar...
# 50  ['Politische Stilkritik: Josef Redl und Barbar...
# 51  ['Politische Stilkritik: Josef Redl und Barbar...
# 52  ['Politische Stilkritik: Josef Redl und Barbar...
# 53  ['Politische Stilkritik: Josef Redl und Barbar...
# 54  ['Politische Stilkritik: Josef Redl und Barbar...
# 55  ['Politische Stilkritik: Josef Redl und Barbar...
# 56  ['Politische Stilkritik: Josef Redl und Barbar...
#
#              compared_article  Similarity
# 42  FALTER_20150916BCE86F6EB1       0.500
# 43  FALTER_20150819A2A890F9AE       0.500
# 44  FALTER_201510077C06FD872C       0.333
# 45  FALTER_201508261C4D7250DD       0.250
# 46  FALTER_2015100713F9AA76C4       0.250
# 47  FALTER_20151104A2A8771AE1       0.250
# 48  FALTER_2015111125F19C1087       0.250
# 49  FALTER_20150826306755BE99       0.000
# 50  FALTER_201508199A870035A6      -0.208
# 51  FALTER_201502044D711CB4F1      -0.208
# 52  FALTER_20150812C9A22FBF21      -0.250
# 53  FALTER_20150826D6220A37BB      -0.292
# 54  FALTER_201508121977F72A0B      -0.417
# 55  FALTER_20150916D574935A27      -0.458
# 56  FALTER_20150527F58CDBC0F6      -0.500

# %% [markdown]
# ## Data Exploration and Viz

# %%
merged.ressort.value_counts().plot(kind="bar", title = "Ressort types", ylabel = "Frequency")
# Out:
# <Axes: title={'center': 'Ressort types'}, ylabel='Frequency'>

# %%
merged.compared_article.value_counts().plot(kind="hist", bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
merged.compared_article.value_counts()
# Out:
# FALTER_20150408A2F8406B8A    37
# FALTER_20151223E758C6E6E3    32
# FALTER_201504085C39421185    29
# FALTER_20151021C174F75E30    25
# FALTER_201510077C06FD872C    24
#                              ..
# FALTER_201504156FCAB44C23     1
# FALTER_2015110460C1FE5811     1
# FALTER_20151125B3EC15F99E     1
# FALTER_20150826153137750B     1
# FALTER_2015020483BDE5657B     1
# Name: compared_article, Length: 1013, dtype: int64

# %%
merged[merged.compared_article=="FALTER_20150408A2F8406B8A"]
# Out:
#                      article_id  \
# 135   FALTER_20151223F6EF9F98C6
# 284   FALTER_201512168BA5823522
# 460   FALTER_201512022198A732A6
# 500   FALTER_20151202BA782CBFBC
# 731   FALTER_2015112583F8A604F8
# 938   FALTER_201511188D537DD3AF
# 1245  FALTER_201511110333C5B366
# 1272  FALTER_201511111E5F134625
# 1632  FALTER_20151021C174F75E30
# 1654  FALTER_2015102169A83D0117
# 2172  FALTER_201510070476E0FB27
# 2236  FALTER_20150930507F0B5C01
# 2599  FALTER_20150923D3A975041D
# 2642  FALTER_20150923261F2DFFE1
# 2793  FALTER_201509163A72B6A30A
# 3501  FALTER_201508268304D98E43
# 3756  FALTER_201508125473E66954
# 3770  FALTER_20150812F9B96FACAB
# 3851  FALTER_20150812732EBDDC6D
# 4000  FALTER_2015072946774F4664
# 4014  FALTER_20150729CFD815CD6D
# 4169  FALTER_20150729F8745604B7
# 4191  FALTER_20150729C142FC1E4D
# 4204  FALTER_201507298439B15B51
# 5178  FALTER_20150610B507E51DFB
# 5592  FALTER_201505135354FBF3D2
# 5662  FALTER_20150513AA0E9A8D1D
# 5912  FALTER_20150506A873C26D65
# 6023  FALTER_201504292FCA902AFD
# 6131  FALTER_201504291DD64AD655
# 6233  FALTER_20150422DC07815993
# 6734  FALTER_201504085881C3EB2C
# 6836  FALTER_20150408AEA913830A
# 7774  FALTER_201502257183F81456
# 7888  FALTER_20150218189E68AF1F
# 8006  FALTER_2015021894109332D4
# 8301  FALTER_201502043AFFDEA0E6
#
#                                                   title  \
# 135                           Die reaktionäre Avantgare
# 284                                   Doch kein Zuckerl
# 460                       Oh mein Gott, was tut ihr da?
# 500                   "Wir haben ein richtiges Problem"
# 731                              Terror im Kinderzimmer
# 938            Ein Mörder mit einem Händchen für Blumen
# 1245            Freud lag ihr näher als Marx und Engels
# 1272  "Wenn ich schon schreibe, dann gleich etwas Ge...
# 1632    "Seid ihr behindert? Ich kann urgut schreiben!"
# 1654                            Die Tante mit der Burka
# 2172               Der Autor als ewiger Weltverbesserer
# 2236                          Der Himmel über Manhattan
# 2599                               Troubles in Paradise
# 2642                            Die Flucht kommt zurück
# 2793                             "Mir war noch nie fad"
# 3501                        Auf der Flucht verschwunden
# 3756                     Die schönsten Platten der Welt
# 3770              Löffelchenliegen? Geh, schleich dich!
# 3851      Gehn Sie weiter, hier gibt es nichts zu sehn!
# 4000                                     Der Aufsteiger
# 4014                        "Überwachung ist wie Liebe"
# 4169                       Der kuriose Fall des Omar S.
# 4191                    Der Peter Ustinov für die Armen
# 4204  Die Nachtigall bekommt einen Nachtwächter gest...
# 5178               Die Dienstmagd mit dem großen Herzen
# 5592                             Das bloßgestellte Kind
# 5662                          Nachsitzen nur freiwillig
# 5912                        Schätze aus der Mottenkiste
# 6023                 "Ihr habt Angst, mich zu benennen"
# 6131                           Kluger Kopf, nobles Herz
# 6233                      Der zündelnde Ex-Benzinbruder
# 6734           Schärfere Paragrafen für die Intimsphäre
# 6836                        Kommen, wenn das Leben geht
# 7774                    Conchitas Regenbogenflüchtlinge
# 7888                      Die Revolution des Fernsehens
# 8006   Nach Kopenhagen: der neue Krieg aller gegen alle
# 8301                             "Es geht um Befreiung"
#
#                                              paragraphs           ressort  \
# 135   ['Oh Tannenbaum, oh Tannenbaum. Die Kerzen str...        Feuilleton
# 284   ['Sie ist kleiner als ein Tic Tac und ihr Nimb...        Stadtleben
# 460   ['Schnellbahn S7, draußen ist es schon dunkel,...           Politik
# 500   ['Was tun, wenn sich ein rassistischer Islam i...           Politik
# 731   ['Es hätte ein unbeschwerter Start ins Wochene...        Stadtleben
# 938   ['Das Schreckliche an Selbstmordattentätern is...        Feuilleton
# 1245  ['Belletristik, im Sinne leichter Unterhaltung...        Feuilleton
# 1272  ['Alles, nur keine Geschichten über Yoga. Lydi...        Feuilleton
# 1632  ['Stefanie Sargnagel ist die lustigste Depress...        Feuilleton
# 1654  ['Nein, das Foto aus der Krone ist nicht gefäl...           Politik
# 2172  ['In seinem letzten Buch "Treibsand. Was es he...        Feuilleton
# 2236  ['Es ist Nacht in New York, Feuerwerke versprü...        Feuilleton
# 2599  ['Dank des deutsch-österreichischen Bahnchaos ...        Feuilleton
# 2642  ['Der Slawonier schlägt das Metalltor vor sein...           Politik
# 2793  ['Zum Gespräch bittet Alfred Komarek in seine ...        Feuilleton
# 3501  ['Zahra umarmt den Laptop und busselt den Bild...           Politik
# 3756  ['Dass Weltenbummler bei Fluggesellschaften an...        Feuilleton
# 3770  ['Es ist wohl eine der kürzesten Sexszenen der...        Feuilleton
# 3851  ['Weil Napoleon in der Schlacht von Aspern bek...        Stadtleben
# 4000  ['Die Van-der-Nüll-Gasse in Favoriten. Das sei...           Politik
# 4014  ['Die deutsche Regisseurin Angela Richter arbe...            Medien
# 4169  ['Diese Musik macht keine Gefangenen. Ein trei...        Feuilleton
# 4191  ['Er war eine imposante Erscheinung. Ein stämm...        Feuilleton
# 4204  ['Ein derartiges Tamtam ist seit dem Erscheine...        Feuilleton
# 5178  ['Ein Name blieb ungenannt, als man sich unlän...        Feuilleton
# 5592  ['Vor 100 Jahren wurde in Amerikas Zeitungen e...            Medien
# 5662  ['Das Ziel von Alternativschulen ist, dass es ...        Stadtleben
# 5912  ['In der Familie Fuchs wird erzählt, dass Opa ...           Politik
# 6023  ['Der deutsche Schauspieler Marius Jung macht ...        Feuilleton
# 6131  ['Das kleine Foto auf der Website des Institut...        Feuilleton
# 6233  ['Der 21. Dezember 2012, ein Datum für die Ges...            Medien
# 6734  ['Jemanden immer wieder zum Rendezvous drängen...           Politik
# 6836  ['Die einzige Hinterlassenschaft seines langen...        Stadtleben
# 7774  ['Conchita hat ihn gerettet. Immer wieder wurd...           Politik
# 7888  ['Am 22. Juni 2008 filmte Elisabeth Wetsch ein...            Medien
# 8006  ['Attentat, diesmal in Kopenhagen. Eine neue S...  Falter & Meinung
# 8301  ['Bestsellerautoren zeichnen sich gewöhnlich n...        Feuilleton
#
#                                               authors  \
# 135                      ['Romanze: Matthias Dusini']
# 284                ['Untersuchung: Birgit Wittstock']
# 460                        ['Reportage: Nina Brnada']
# 500                       ['Gespräch: Florian Klenk']
# 731   ['Umfrage: Georg Renöckl und Birgit Wittstock']
# 938                       ['Lektüre: Klaus Nüchtern']
# 1245                      ['Porträt: Michael Omasta']
# 1272                ['Porträts: Sebastian Fasthuber']
# 1632   ['Interview: Klaus Nüchtern & Gerhard Stöger']
# 1654                       ['Bericht: Florian Klenk']
# 2172                 ['Nachruf: Sebastian Fasthuber']
# 2236               ['Begegnung: Stefanie Panzenböck']
# 2599                         ['Wort: Klaus Nüchtern']
# 2642    ['Reportage und Fotos: Nina Brnada/Tovarnik']
# 2793               ['Interview: Sebastian Fasthuber']
# 3501                       ['Bericht: Nina Horaczek']
# 3756                 ['Porträt: Sebastian Fasthuber']
# 3770                 ['Paartherapie: Klaus Nüchtern']
# 3851                   ['Wanderwart: Klaus Nüchtern']
# 4000                         ['Porträt: Nina Brnada']
# 4014            ['Interview: Benedikt Narodoslawsky']
# 4169                 ['Porträt: Sebastian Fasthuber']
# 4191                      ['Nachruf: Michael Omasta']
# 4204                      ['Lektüre: Klaus Nüchtern']
# 5178                 ['Lektüre: Sebastian Fasthuber']
# 5592                       ['Bericht: Florian Klenk']
# 5662                       ['Reportage: Nina Brnada']
# 5912                      ['Überblick: Barbara Tóth']
# 6023                   ['Interview: Matthias Dusini']
# 6131                      ['Nachruf: Klaus Nüchtern']
# 6233              ['Porträt: Benedikt Narodoslawsky']
# 6734                        ['Bericht: Barbara Tóth']
# 6836                    ['Porträt: Birgit Wittstock']
# 7774                       ['Bericht: Nina Horaczek']
# 7888     ['Jubiläumsschrift: Benedikt Narodoslawsky']
# 8006                               ['Armin Thurnher']
# 8301               ['Interview: Sebastian Fasthuber']
#
#                compared_article  Similarity
# 135   FALTER_20150408A2F8406B8A       0.375
# 284   FALTER_20150408A2F8406B8A      -0.167
# 460   FALTER_20150408A2F8406B8A       0.375
# 500   FALTER_20150408A2F8406B8A      -0.292
# 731   FALTER_20150408A2F8406B8A      -0.167
# 938   FALTER_20150408A2F8406B8A      -0.812
# 1245  FALTER_20150408A2F8406B8A      -0.958
# 1272  FALTER_20150408A2F8406B8A      -0.375
# 1632  FALTER_20150408A2F8406B8A      -0.200
# 1654  FALTER_20150408A2F8406B8A       0.375
# 2172  FALTER_20150408A2F8406B8A      -0.542
# 2236  FALTER_20150408A2F8406B8A      -0.167
# 2599  FALTER_20150408A2F8406B8A       0.083
# 2642  FALTER_20150408A2F8406B8A      -0.562
# 2793  FALTER_20150408A2F8406B8A      -0.562
# 3501  FALTER_20150408A2F8406B8A      -0.667
# 3756  FALTER_20150408A2F8406B8A      -0.958
# 3770  FALTER_20150408A2F8406B8A      -0.875
# 3851  FALTER_20150408A2F8406B8A      -0.667
# 4000  FALTER_20150408A2F8406B8A      -0.562
# 4014  FALTER_20150408A2F8406B8A      -0.750
# 4169  FALTER_20150408A2F8406B8A      -0.042
# 4191  FALTER_20150408A2F8406B8A      -0.333
# 4204  FALTER_20150408A2F8406B8A      -0.312
# 5178  FALTER_20150408A2F8406B8A      -0.375
# 5592  FALTER_20150408A2F8406B8A       0.042
# 5662  FALTER_20150408A2F8406B8A       0.250
# 5912  FALTER_20150408A2F8406B8A      -0.750
# 6023  FALTER_20150408A2F8406B8A      -0.167
# 6131  FALTER_20150408A2F8406B8A      -0.542
# 6233  FALTER_20150408A2F8406B8A      -0.208
# 6734  FALTER_20150408A2F8406B8A      -0.708
# 6836  FALTER_20150408A2F8406B8A      -0.375
# 7774  FALTER_20150408A2F8406B8A      -0.542
# 7888  FALTER_20150408A2F8406B8A      -0.458
# 8006  FALTER_20150408A2F8406B8A      -0.042
# 8301  FALTER_20150408A2F8406B8A      -0.583

# %%
merged[merged.compared_article=="FALTER_2015020483BDE5657B"]
# Out:
#                      article_id                   title  \
# 8289  FALTER_201502043AFFDEA0E6  "Es geht um Befreiung"
#
#                                              paragraphs     ressort  \
# 8289  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
#
#                                  authors           compared_article  \
# 8289  ['Interview: Sebastian Fasthuber']  FALTER_2015020483BDE5657B
#
#       Similarity
# 8289       0.708

# %%
merged[merged.compared_article=="FALTER_2015110460C1FE5811"]
# Out:
#                      article_id                       title  \
# 2837  FALTER_201509168688A8BF8F  Keine Frage des Geschmacks
#
#                                              paragraphs     ressort  \
# 2837  ['Kulturstadtrat Andreas Mailath-Pokorny hat k...  Feuilleton
#
#                               authors           compared_article  Similarity
# 2837  ['Bilanz: Stefanie Panzenböck']  FALTER_2015110460C1FE5811       0.833

# %%
plt_sim_hit = merged.Similarity.hist(bins = 13)
plt_sim_hit.set_xlabel("Similarity values")
plt_sim_hit.set_title("Frequency of the similarity values")
plt.show()

# %% [markdown]
# ## Data Cleaining and Text prep

# %%
dftext = pd.DataFrame()

# %%
merged.text = merged.paragraphs+ " "+merged.title + " " + merged.ressort + " " + merged.authors
# Out:
# /tmp/ipykernel_283/867120368.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   merged.text = merged.paragraphs+ " "+merged.title + " " + merged.ressort + " " + merged.authors

# %%
merged.text = merged.text.fillna(" ")

# %%
merged.text.isna().sum()
# Out:
# 0

# %%
def clean(review):
    if isinstance(review, str):
        review = review.lower()
        review = re.sub('[^a-z A-Z 0-9-]+', '', review)
        review = " ".join([word for word in review.split() if word not in stopwords.words('german')])
        
        return review

# %%
merged.text = merged.text.apply(clean)

# %%
merged.text
# Out:
# 0       kinderwagen drngen eingangstr wolfgang puchers...
# 1       handbuch kolumnenschreiberei sieht letzte glos...
# 2       xenia fotografin 22 zwei jahren tag zuhause ge...
# 3       zuerst korrektur irrtums ama betrieb restauran...
# 4       wann feiert kabarettist eigentlich silvester a...
#                               ...
# 8669    konzept einfach schlssig zugereiste wiener mus...
# 8670    drei songs viereinhalb minuten lime crush setz...
# 8671    warum mssen menschen krieg elend flchten masse...
# 8672    sammler getriebene gilt fr bchersammler seit 1...
# 8673    kickdrum zischt dampft snares rollen triolen h...
# Length: 8674, dtype: object

# %%
merged.text[0]
# Out:
# 'kinderwagen drngen eingangstr wolfgang puchers pfarrhaus gehren 30 rumnischen roma kellergescho beherbergt obergescho wohnt auerdem junge roma-familie pucher junge mdchen hochschwanger abbruchhaus geholt pfarrhaus zieht vanilleduft frauen mnner vinzitel backen heute kekse bank puchers bro schlft mann pfarrer steckt schnell rum-kokos-kugel mund bevor interview setzt geschenkt bekommen pucher bekommt viele geschenke wunder 76-jhrige 38 sozialprojekte aufgestellt vinzidorf fr obdachlose alkoholkranke mnner vinzipasta slowakischen hostice roma-frauen nudeln herstellen 39 einrichtung erst seit kurzem fix vinzidorf fr wien 13 jahre pucher dafr gekmpft nchste ziel vinzidorf fr frauen graz falter herr pfarrer schon adventstimmung eingestellt tun recht kommen wolfgang pucher beruf schwer viele pflichttermine gibt drei ereignisse schenken jahr besinnung erstens gottesdienst frauen unserer pfarrgemeinde selber musizieren nachher sitzen zusammen keks punsch zweitens mittwoch advent rorate frhmesse advent anm strae kapelle dekorieren 30 laternen einfach innig drittens wandere jahr mnnern pfarrgemeinde leechwald laternen schweigend kirche mariagrn verbringen heiligen abend pucher kindermette leider hektisch auto vinzidorf fahren weihnachtsfeier schnste gibt chor welt stille nacht schner singt mnner vinzidorf groe sehnsuchtsvolle derb klingende hoffnung leben fr brig danach feiern vinzitel nachdenkliche feier viele drogenabhngig dankbar kurzes zuhause 22 uhr halte mette heimgehen stimmung pucher gehe wohnund schlafbereich entznde kleinen christbaum kerzen vllig allein mitternacht manchmal geschenken bekommen kommt natrlich immer erinnerung kindheit armut mutter weihnachten mehr fehlt jemals schwester schon verstorben ganze kindheit lang gefroren weihnachten wurde einzige mal jahr eingeheizt erinnerungen kommen weihnachten kindheit denken pucher mittelpunkt steht immer mutter witwe vier uhr frh spt abend arbeiten viele kleine tiere versorgen herd kchelten frhen morgen kartoffeln fr schwein geschenke socken gestrickt hauben handschuhe dinge sowieso gebraucht unglaublich viele ideen entfaltet drei kindern heilen heiligen welt vermitteln haus zwei rume schlafzimmer eingeheizt ber ofen engelspiel gestellt spitze kleines windrad darunter hingen drei engel stab rand drei glcklein wrme hochgestiegen begann ganz leise klingeln ding-ding ding-ding wussten christkind augenblick beschreiben ja geglaubt christkind gekommen natrlich ansehen weihnachten heute oft gefeiert -mit alkohol stress einkaufen - wrden menschen wnschen pucher schwierig wnscht gutgeht gut geht fehlt bewusstsein leben berhaupt geschenk mehr lage geschenke wahrzunehmen fr finden grauenhaft heutzutage oft gleich dazusagt kannst umtauschen verkommene geschenkskultur erfahrung beschenkt fast mglich bewusst bisschen armut fr selber sucht zurckkehrt einfachheit fr wohl geschenk 13 jahren endlich vinzidorf wien bauen drfen wien schwieriger pucher nein brgerversammlungen graz genauso wild aggressiv nachbarn frher angedachten standorts wien architekten worten begegnet gar wiedergeben beim aktuellen standort wild zugegangen sicher schnell legen leute merken fr gefahr davon ausgeht november silberne ehrenzeichen republik berreicht bekommen sagten hasse satz geht hasse satz wer hasse satz wer zahlen stze fallen oft bezug flchtlingskrise gibt grenzen pucher genauso ratlos momentan bewundere frau merkel ber fr mut trotz ablehnung dabei bleiben obergrenze festlegt sehen vergleich sterreichische politik pucher lavieren hilfsbereitschaft knnen leisten bzw knnen menschen zumuten linie merkel erkennbar kirche sehen luft oben pucher natrlich sehe ganzen gesellschaft viele menschen zweitwohnsitze viele leben berdurchschnittlich groen wohnung wissens gibt pfarrhaus zumindest raum frei wre politik unterscheidet kriegsund wirtschaftsflchtlingen pucher hunger genauso tdlich terror is roma osteuropa zehn jahre niedrigere lebenserwartung rest bevlkerung tod raten leute 20 schon kaputte zhne langsamere minder g ...

# %%
merged.to_csv("cleaned.csv")

# %%
merged["text"] = merged.text

# %%
merged
# Out:
#                      article_id  \
# 0     FALTER_201512234F1D30CEA9
# 1     FALTER_2015122382119EA87A
# 2     FALTER_2015122317D031535C
# 3     FALTER_20151223D853291AAA
# 4     FALTER_201512238A0DEB6E2D
# ...                         ...
# 8669  FALTER_20150114D1B1464B21
# 8670  FALTER_20150114100173AA99
# 8671  FALTER_201501144F8F9DDBEE
# 8672  FALTER_201501143FF6C01FA5
# 8673  FALTER_20150114D27133E690
#
#                                                   title  \
# 0                    "Bewundere Frau Merkel über alles"
# 1                                           Wildbretter
# 2     Warum es ganz normal sein kann, zwei Zuhause z...
# 3                                      Der Lerchenfisch
# 4                      Uhudler-Orbán und Kernölamazonen
# ...                                                 ...
# 8669             Achte Ausgabe des Festivals in between
# 8670             Punkrock der Marke "Ned deppert sein!"
# 8671  Mit einem Flüchtling in der WG: Neue Initiativ...
# 8672                          Büchersonntag in Hietzing
# 8673  Neuer Floor, neue Party: ein guter Start ins P...
#
#                                              paragraphs      ressort  \
# 0     ['Kinderwagen drängen sich bei der Eingangstür...   Steiermark
# 1     ['Das Handbuch der Kolumnenschreiberei sieht v...  Falters Zoo
# 2     ['Xenia, Fotografin, 22', 'Ich habe bis vor zw...   Stadtleben
# 3     ['Zuerst Korrektur eines Irrtums: Nicht die AM...   Stadtleben
# 4     ['Wann feiert ein Kabarettist eigentlich Silve...      Lexikon
# ...                                                 ...          ...
# 8669  ['Das Konzept ist so einfach wie schlüssig: Zu...      Lexikon
# 8670  ['Drei Songs in viereinhalb Minuten: Lime Crus...      Lexikon
# 8671  ['Warum müssen Menschen, die vor Krieg und Ele...      Politik
# 8672  ['Sammler sind Getriebene, das gilt auch für B...      Lexikon
# 8673  ['Die Kickdrum zischt und dampft, die Snares r...      Lexikon
#
#                                                 authors compared_article  \
# 0                       ['INTERVIEW: GERLINDE PÖLSLER']              NaN
# 1                                                    []              NaN
# 2                           ['RECHERCHE: BARBARA TÓTH']              NaN
# 3                       ['LOKALKRITIK: FLORIAN HOLZER']              NaN
# 4     ['SILVESTEREXPERTISE: STEFANIE PANZENBÖCK UND ...              NaN
# ...                                                 ...              ...
# 8669                                             ['GS']              NaN
# 8670                                                 []              NaN
# 8671                         ['BENEDIKT NARODOSLAWSKY']              NaN
# 8672                                                 []              NaN
# 8673                              ['Katharina Seidler']              NaN
#
#       Similarity                                               text
# 0            NaN  kinderwagen drngen eingangstr wolfgang puchers...
# 1            NaN  handbuch kolumnenschreiberei sieht letzte glos...
# 2            NaN  xenia fotografin 22 zwei jahren tag zuhause ge...
# 3            NaN  zuerst korrektur irrtums ama betrieb restauran...
# 4            NaN  wann feiert kabarettist eigentlich silvester a...
# ...          ...                                                ...
# 8669         NaN  konzept einfach schlssig zugereiste wiener mus...
# 8670         NaN  drei songs viereinhalb minuten lime crush setz...
# 8671         NaN  warum mssen menschen krieg elend flchten masse...
# 8672         NaN  sammler getriebene gilt fr bchersammler seit 1...
# 8673         NaN  kickdrum zischt dampft snares rollen triolen h...
#
# [8674 rows x 8 columns]

# %% [markdown]
# Get Top Most important words

# %%
newdf["text"] = newdf.paragraphs + " " + newdf.title + " " + newdf.ressort + " " + newdf.authors
# Out:
# /tmp/ipykernel_348/189060552.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf["text"] = newdf.paragraphs + " " + newdf.title + " " + newdf.ressort + " " + newdf.authors

# %%
newdf["text"] = newdf["text"].fillna(" ")
# Out:
# /tmp/ipykernel_348/1447610670.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf["text"] = newdf["text"].fillna(" ")

# %%
newdf["text"].isna().sum()
# Out:
# 0

# %%
newdf.text = newdf.text.apply(clean)
# Out:
# /tmp/ipykernel_348/1117155853.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf.text = newdf.text.apply(clean)

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(newdf.text)

# %%
newdf.text.isna().sum()
# Out:
# 0

# %%
newdf.title.isna().sum()
# Out:
# 0

# %%
newdf.text
# Out:
# 0       kinderwagen drngen eingangstr wolfgang puchers...
# 1       handbuch kolumnenschreiberei sieht letzte glos...
# 2       xenia fotografin 22 zwei jahren tag zuhause ge...
# 3       zuerst korrektur irrtums ama betrieb restauran...
# 4       wann feiert kabarettist eigentlich silvester a...
#                               ...
# 5911    konzept einfach schlssig zugereiste wiener mus...
# 5912    drei songs viereinhalb minuten lime crush setz...
# 5913    warum mssen menschen krieg elend flchten masse...
# 5914    sammler getriebene gilt fr bchersammler seit 1...
# 5915    kickdrum zischt dampft snares rollen triolen h...
# Name: text, Length: 5916, dtype: object

# %%
# Retrieve feature names
feature_names = vectorizer.get_feature_names_out()

# Get IDF scores
idf_scores = vectorizer.idf_

# Combine feature names and IDF scores
features_with_scores = list(zip(feature_names, idf_scores))

# Sort the list based on IDF scores
sorted_features = sorted(features_with_scores, key=lambda x: x[1], reverse=True)

# Specify the number of top words to retrieve
top_n = 100

# Retrieve the top N words
top_words = sorted_features[:top_n]

# Print the top words and their IDF scores
for word, score in top_words:
    print(f"Word: {word}, IDF Score: {score}")
# Out:
# Word: 0002, IDF Score: 8.99243766211675
# Word: 001, IDF Score: 8.99243766211675
# Word: 004, IDF Score: 8.99243766211675
# Word: 0045, IDF Score: 8.99243766211675
# Word: 011, IDF Score: 8.99243766211675
# Word: 01112015, IDF Score: 8.99243766211675
# Word: 01196, IDF Score: 8.99243766211675
# Word: 012012, IDF Score: 8.99243766211675
# Word: 01203, IDF Score: 8.99243766211675
# Word: 01214, IDF Score: 8.99243766211675
# Word: 01216, IDF Score: 8.99243766211675
# Word: 0123, IDF Score: 8.99243766211675
# Word: 01235, IDF Score: 8.99243766211675
# Word: 01236, IDF Score: 8.99243766211675
# Word: 01241, IDF Score: 8.99243766211675
# Word: 01245, IDF Score: 8.99243766211675
# Word: 0125, IDF Score: 8.99243766211675
# Word: 01258, IDF Score: 8.99243766211675
# Word: 01263, IDF Score: 8.99243766211675
# Word: 01293, IDF Score: 8.99243766211675
# Word: 013, IDF Score: 8.99243766211675
# Word: 01318, IDF Score: 8.99243766211675
# Word: 01320, IDF Score: 8.99243766211675
# Word: 01328, IDF Score: 8.99243766211675
# Word: 01333, IDF Score: 8.99243766211675
# Word: 0134, IDF Score: 8.99243766211675
# Word: 01352, IDF Score: 8.99243766211675
# Word: 01367, IDF Score: 8.99243766211675
# Word: 01370, IDF Score: 8.99243766211675
# Word: 01388, IDF Score: 8.99243766211675
# Word: 01401, IDF Score: 8.99243766211675
# Word: 01408, IDF Score: 8.99243766211675
# Word: 01470, IDF Score: 8.99243766211675
# Word: 01476, IDF Score: 8.99243766211675
# Word: 01480, IDF Score: 8.99243766211675
# Word: 01486, IDF Score: 8.99243766211675
# Word: 01489, IDF Score: 8.99243766211675
# Word: 01503, IDF Score: 8.99243766211675
# Word: 01505, IDF Score: 8.99243766211675
# Word: 01515, IDF Score: 8.99243766211675
# Word: 01524, IDF Score: 8.99243766211675
# Word: 01595, IDF Score: 8.99243766211675
# Word: 01596, IDF Score: 8.99243766211675
# Word: 01597, IDF Score: 8.99243766211675
# Word: 01602, IDF Score: 8.99243766211675
# Word: 01688, IDF Score: 8.99243766211675
# Word: 01698, IDF Score: 8.99243766211675
# Word: 017, IDF Score: 8.99243766211675
# Word: 01710, IDF Score: 8.99243766211675
# Word: 01713, IDF Score: 8.99243766211675
# Word: 01718, IDF Score: 8.99243766211675
# Word: 01749, IDF Score: 8.99243766211675
# Word: 01786, IDF Score: 8.99243766211675
# Word: 01796, IDF Score: 8.99243766211675
# Word: 01803, IDF Score: 8.99243766211675
# Word: 01812, IDF Score: 8.99243766211675
# Word: 01813, IDF Score: 8.99243766211675
# Word: 01815, IDF Score: 8.99243766211675
# Word: 01865, IDF Score: 8.99243766211675
# Word: 01878, IDF Score: 8.99243766211675
# Word: 01888, IDF Score: 8.99243766211675
# Word: 01889, IDF Score: 8.99243766211675
# Word: 01892, IDF Score: 8.99243766211675
# Word: 01893, IDF Score: 8.99243766211675
# Word: 01905, IDF Score: 8.99243766211675
# Word: 01908, IDF Score: 8.99243766211675
# Word: 0191, IDF Score: 8.99243766211675
# Word: 01920, IDF Score: 8.99243766211675
# Word: 01922, IDF Score: 8.99243766211675
# Word: 01923, IDF Score: 8.99243766211675
# Word: 01941, IDF Score: 8.99243766211675
# Word: 01942, IDF Score: 8.99243766211675
# Word: 01945, IDF Score: 8.99243766211675
# Word: 01952, IDF Score: 8.99243766211675
# Word: 01971, IDF Score: 8.99243766211675
# Word: 01979, IDF Score: 8.99243766211675
# Word: 0210a, IDF Score: 8.99243766211675
# Word: 02236210, IDF Score: 8.99243766211675
# Word: 0224822, IDF Score: 8.99243766211675
# Word: 0226866, IDF Score: 8.99243766211675
# Word: 0252482, IDF Score: 8.99243766211675
# Word: 027, IDF Score: 8.99243766211675
# Word: 0273922, IDF Score: 8.99243766211675
# Word: 031635, IDF Score: 8.99243766211675
# Word: 031638, IDF Score: 8.99243766211675
# Word: 031642, IDF Score: 8.99243766211675
# Word: 031648, IDF Score: 8.99243766211675
# Word: 031667, IDF Score: 8.99243766211675
# Word: 031668, IDF Score: 8.99243766211675
# Word: 03168015, IDF Score: 8.99243766211675
# Word: 0316815625, IDF Score: 8.99243766211675
# Word: 031684, IDF Score: 8.99243766211675
# Word: 0316872, IDF Score: 8.99243766211675
# Word: 0316877, IDF Score: 8.99243766211675
# Word: 0318583, IDF Score: 8.99243766211675
# Word: 032, IDF Score: 8.99243766211675
# Word: 03316822, IDF Score: 8.99243766211675
# Word: 03352321, IDF Score: 8.99243766211675
# Word: 039, IDF Score: 8.99243766211675
# Word: 045, IDF Score: 8.99243766211675

# %%
feature_names = vectorizer.get_feature_names_out()

top_n = 80

# %%
# Create an empty list to store the top words for each text
top_words_per_text = []

# %%
for i, text in enumerate(newdf.text):
    # Transform the text into a TF-IDF vector
    tfidf_vector = vectorizer.transform([text])

    # Get the TF-IDF scores for the text
    tfidf_scores = zip(feature_names, tfidf_vector.toarray()[0])

    # Sort the TF-IDF scores in descending order
    sorted_scores = sorted(tfidf_scores, key=lambda x: x[1], reverse=True)

    # Retrieve the top N words for the text
    top_words = [word for word, score in sorted_scores[:top_n]]

    # Store the top words for the text in the dictionary
    
        # Combine the top words into a single string
    top_words_text = ' '.join(top_words)

    # Store the top words for the text in the list
    top_words_per_text.append(top_words_text)

# %%
df_picked = pd.DataFrame({'Top_Words': top_words_per_text})

# %%
df_picked
# Out:
#                                               Top_Words
# 0     pucher vinzidorf roma frauen pfarrhaus fr weih...
# 1     vanillekipferln wildtier darf echt abfassen ad...
# 2     vater eltern mutter wechselmodell zuhause dopp...
# 3     eishken tel fisch austern fischgeschft estate ...
# 4     silvester uhr kabarettist 2230 maurer special ...
# ...                                                 ...
# 5911  between akzent angelacht baheux dreiteilig klo...
# 5912  219 lime crush mc deppert ned marke akademie h...
# 5913  zistl initiative flchtlinge asylwerber kontakt...
# 5914  hietzing bchersonntag vhs austriaca bchersamml...
# 5915  music ikonika position bass club caf clubs cel...
#
# [5916 rows x 1 columns]

# %%
df_picked["article_id"] = newdf.article_id

# %%
df_picked
# Out:
#                                               Top_Words  \
# 0     pucher vinzidorf roma frauen pfarrhaus fr weih...
# 1     vanillekipferln wildtier darf echt abfassen ad...
# 2     vater eltern mutter wechselmodell zuhause dopp...
# 3     eishken tel fisch austern fischgeschft estate ...
# 4     silvester uhr kabarettist 2230 maurer special ...
# ...                                                 ...
# 5911  between akzent angelacht baheux dreiteilig klo...
# 5912  219 lime crush mc deppert ned marke akademie h...
# 5913  zistl initiative flchtlinge asylwerber kontakt...
# 5914  hietzing bchersonntag vhs austriaca bchersamml...
# 5915  music ikonika position bass club caf clubs cel...
#
#                      article_id
# 0     FALTER_201512234F1D30CEA9
# 1     FALTER_2015122382119EA87A
# 2     FALTER_2015122317D031535C
# 3     FALTER_20151223D853291AAA
# 4     FALTER_201512238A0DEB6E2D
# ...                         ...
# 5911  FALTER_20150114D1B1464B21
# 5912  FALTER_20150114100173AA99
# 5913  FALTER_201501144F8F9DDBEE
# 5914  FALTER_201501143FF6C01FA5
# 5915  FALTER_20150114D27133E690
#
# [5916 rows x 2 columns]

# %%
df_picked.to_csv("top_80.csv")

# %%
df_picked.Top_Words[0]
# Out:
# 'pucher vinzidorf roma frauen pfarrhaus fr weihnachten ding hasse geschenke pfarrer viele eingeheizt laternen puchers vinzitel zlibat papst pfarrgemeinde vinziwerke bewundere merkel kindheit kirche gott schdel christkind satz leute mehr geglaubt priester obdachlose advent waschen wien genauso 76 gesagt kommen wolfgang flchtlingskrise heiligen mnner schwer sicher menschheit armut schnell 38 einrichtung leben wild graz gibt drei ganze geschenk bekommen ja hast geld menschen schon bzw knnen wieso oft vorstellen warum gehen fallen bevlkerung natrlich sehen fehlt suchen frau adventstimmung alkoholkranke'

# %%
from langchain.embeddings import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="bert-base-german-cased")

query_result = embeddings.embed_documents(df_picked.Top_Words)
# Out:
# No sentence-transformers model found with name /home/e12141198/.cache/torch/sentence_transformers/bert-base-german-cased. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at /home/e12141198/.cache/torch/sentence_transformers/bert-base-german-cased were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# # df_picked.Top_Words

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

def get_topk_similar_articles(embeddings, article_index, k, negativSimilartiy=False):
    """
    Get the top k news articles with highest similarity for a given index
    
    embeddings: embeddings matrix
    article_index: target article
    k = get the top k articles
    include_negative: if abs values should be used
    return top articles for given index
    """

    # Calculate pairwise cosine similarity with sklearn library
    similarity_scores = cosine_similarity(embeddings)
    
    # get similarity scores for the given article index
    article_scores = similarity_scores[article_index]
        
    # get negative similarity or positive ones
    # argsort returns the indices of the sorted array
    if negativSimilartiy:
        # [:k] to return only the top k article indices 
        sorted_indices = np.argsort(article_scores)[:k] 
    else:
        # [::-1] to order in decending order
        # 1:k+1 to exclude the target-article itself (similartiy = 1)
        sorted_indices = np.argsort(article_scores)[::-1][1:k+1] 
    
    # Get the top k (anti-) similar articles
    top_articles = [(index, article_scores[index]) for index in sorted_indices if index != article_index]
 
    return top_articles

# %%
# TEST Function with and without abs-values

target_article = 10
k = 5

# Get top similar articles for article at index 0
top_articles = get_topk_similar_articles(query_result, target_article, k, negativSimilartiy=False)

print(f"Top {k} Articles for Index: {target_article}:")
# Print the top similar articles
for article_index, similarity in top_articles:
    print(f"Article Index: {article_index}, Similarity Score: {similarity}")

    
    
# Get top anti-similar articles for article at index 0
top_articles = get_topk_similar_articles(query_result, target_article, k, negativSimilartiy=True)

print(f"\nTop {k} anti-similar Articles for Index: {target_article}:")
# Print the top similar articles
for article_index, similarity in top_articles:
    print(f"Article Index: {article_index}, Similarity Score: {similarity}")
# Out:
# Top 5 Articles for Index: 10:
# Article Index: 1000, Similarity Score: 0.9822871361174459
# Article Index: 2390, Similarity Score: 0.9810752134711761
# Article Index: 141, Similarity Score: 0.9809528437897908
# Article Index: 3298, Similarity Score: 0.980752374472709
# Article Index: 3075, Similarity Score: 0.9800219792777912
#
# Top 5 anti-similar Articles for Index: 10:
# Article Index: 2957, Similarity Score: 0.3843644160545452
# Article Index: 3516, Similarity Score: 0.3843644160545452
# Article Index: 3515, Similarity Score: 0.3843644160545452
# Article Index: 3514, Similarity Score: 0.3843644160545452
# Article Index: 3513, Similarity Score: 0.3843644160545452

# %%
from langchain.embeddings import FakeEmbeddings
fakeemb = FakeEmbeddings(size=768)
embd = fakeemb.embed_documents(df_picked.Top_Words)

# %%
# TEST Function with and without abs-values

target_article = 10
k = 5

# Get top similar articles for article at index 0
top_articles = get_topk_similar_articles(embd, target_article, k, negativSimilartiy=False)

print(f"Top {k} Articles for Index: {target_article}:")
# Print the top similar articles
for article_index, similarity in top_articles:
    print(f"Article Index: {article_index}, Similarity Score: {similarity}")

    
    
# Get top anti-similar articles for article at index 0
top_articles = get_topk_similar_articles(embd, target_article, k, negativSimilartiy=True)

print(f"\nTop {k} anti-similar Articles for Index: {target_article}:")
# Print the top similar articles
for article_index, similarity in top_articles:
    print(f"Article Index: {article_index}, Similarity Score: {similarity}")
# Out:
# Top 5 Articles for Index: 10:
# Article Index: 156, Similarity Score: 0.13535004151911476
# Article Index: 5603, Similarity Score: 0.13502127013871068
# Article Index: 359, Similarity Score: 0.11818287864388721
# Article Index: 53, Similarity Score: 0.11412338208453998
# Article Index: 4434, Similarity Score: 0.11008302661050105
#
# Top 5 anti-similar Articles for Index: 10:
# Article Index: 1639, Similarity Score: -0.13025063609498147
# Article Index: 598, Similarity Score: -0.11841592054532696
# Article Index: 4321, Similarity Score: -0.11581797274245445
# Article Index: 2391, Similarity Score: -0.11352067993050907
# Article Index: 5653, Similarity Score: -0.11231480804556848

# %%
file_name = "huggingface.pkl"

open_file = open(file_name, "wb")
pickle.dump(query_result, open_file) 
open_file.close()

# %%
open_file = open(file_name, "rb")
loaded_list = pickle.load(open_file)
open_file.close()

# %%
from langchain.embeddings import OpenAIEmbeddings
openai = OpenAIEmbeddings(openai_api_key="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")

# %%
openai = openai.embed_documents(df_picked.Top_Words)

# %%
file_name = "openaiembed.pkl"

open_file = open(file_name, "wb")
pickle.dump(openai, open_file) # !!!!!!!!!!!!!!!!!!!!!!!!!should not it be openai instead query_results????
open_file.close()

# %%
# TEST Function with and without abs-values

target_article = 10
k = 5

# Get top similar articles for article at index 0
top_articles = get_topk_similar_articles(openai, target_article, k, negativSimilartiy=False)

print(f"Top {k} Articles for Index: {target_article}:")
# Print the top similar articles
for article_index, similarity in top_articles:
    print(f"Article Index: {article_index}, Similarity Score: {similarity}")

    
    
# Get top anti-similar articles for article at index 0
top_articles = get_topk_similar_articles(openai, target_article, k, negativSimilartiy=True)

print(f"\nTop {k} anti-similar Articles for Index: {target_article}:")
# Print the top similar articles
for article_index, similarity in top_articles:
    print(f"Article Index: {article_index}, Similarity Score: {similarity}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 k = 5
#       6 # Get top similar articles for article at index 0
# ----> 7 top_articles = get_topk_similar_articles(openai, target_article, k, negativSimilartiy=False)
#       9 print(f"Top {k} Articles for Index: {target_article}:")
#      10 # Print the top similar articles
#
# NameError: name 'get_topk_similar_articles' is not defined

# %% [markdown]
# # Start From Here

# %%
df_cleaned = pd.read_csv("../data/cleaned.csv", index_col=False).drop("Unnamed: 0", axis = 1)

# %%
demo = pd.read_csv("../data/cleaned_text.csv", index_col=False).drop("Unnamed: 0", axis = 1)
demo
# Out:
#                      article_id  \
# 0     FALTER_201512234F1D30CEA9
# 1     FALTER_2015122382119EA87A
# 2     FALTER_2015122317D031535C
# 3     FALTER_20151223D853291AAA
# 4     FALTER_201512238A0DEB6E2D
# ...                         ...
# 5911  FALTER_20150114D1B1464B21
# 5912  FALTER_20150114100173AA99
# 5913  FALTER_201501144F8F9DDBEE
# 5914  FALTER_201501143FF6C01FA5
# 5915  FALTER_20150114D27133E690
#
#                                                   title  \
# 0                    "Bewundere Frau Merkel über alles"
# 1                                           Wildbretter
# 2     Warum es ganz normal sein kann, zwei Zuhause z...
# 3                                      Der Lerchenfisch
# 4                      Uhudler-Orbán und Kernölamazonen
# ...                                                 ...
# 5911             Achte Ausgabe des Festivals in between
# 5912             Punkrock der Marke "Ned deppert sein!"
# 5913  Mit einem Flüchtling in der WG: Neue Initiativ...
# 5914                          Büchersonntag in Hietzing
# 5915  Neuer Floor, neue Party: ein guter Start ins P...
#
#                                              paragraphs      ressort  \
# 0     ['Kinderwagen drängen sich bei der Eingangstür...   Steiermark
# 1     ['Das Handbuch der Kolumnenschreiberei sieht v...  Falters Zoo
# 2     ['Xenia, Fotografin, 22', 'Ich habe bis vor zw...   Stadtleben
# 3     ['Zuerst Korrektur eines Irrtums: Nicht die AM...   Stadtleben
# 4     ['Wann feiert ein Kabarettist eigentlich Silve...      Lexikon
# ...                                                 ...          ...
# 5911  ['Das Konzept ist so einfach wie schlüssig: Zu...      Lexikon
# 5912  ['Drei Songs in viereinhalb Minuten: Lime Crus...      Lexikon
# 5913  ['Warum müssen Menschen, die vor Krieg und Ele...      Politik
# 5914  ['Sammler sind Getriebene, das gilt auch für B...      Lexikon
# 5915  ['Die Kickdrum zischt und dampft, die Snares r...      Lexikon
#
#                                      authors                       date  \
# 0                           gerlinde pölsler  2015-12-23 00:00:00+00:00
# 1                                        NaN  2015-12-23 00:00:00+00:00
# 2                               barbara tóth  2015-12-23 00:00:00+00:00
# 3                             florian holzer  2015-12-23 00:00:00+00:00
# 4     stefanie panzenböck, sara schausberger  2015-12-23 00:00:00+00:00
# ...                                      ...                        ...
# 5911                                      gs  2015-01-14 00:00:00+00:00
# 5912                                     NaN  2015-01-14 00:00:00+00:00
# 5913                  benedikt narodoslawsky  2015-01-14 00:00:00+00:00
# 5914                                     NaN  2015-01-14 00:00:00+00:00
# 5915                       katharina seidler  2015-01-14 00:00:00+00:00
#
#                                            text_cleaned
# 0     kinderwagen drngen eingangstr wolfgang puchers...
# 1     handbuch kolumnenschreiberei sieht letzte glos...
# 2     xenia fotografin 22 zwei jahren tag zuhause ge...
# 3     zuerst korrektur irrtums ama betrieb restauran...
# 4     wann feiert kabarettist eigentlich silvester a...
# ...                                                 ...
# 5911  konzept einfach schlssig zugereiste wiener mus...
# 5912  drei songs viereinhalb minuten lime crush setz...
# 5913  warum mssen menschen krieg elend flchten masse...
# 5914  sammler getriebene gilt fr bchersammler seit 1...
# 5915  kickdrum zischt dampft snares rollen triolen h...
#
# [5916 rows x 7 columns]

# %%
df_picked = pd.read_csv("../data/top_80.csv")
df_picked.drop("Unnamed: 0", axis=1, inplace=True)
df_picked
# Out:
#                                               Top_Words  \
# 0     pucher vinzidorf roma frauen pfarrhaus fr weih...
# 1     vanillekipferln wildtier darf echt abfassen ad...
# 2     vater eltern mutter wechselmodell zuhause dopp...
# 3     eishken tel fisch austern fischgeschft estate ...
# 4     silvester uhr kabarettist 2230 maurer special ...
# ...                                                 ...
# 5911  between akzent angelacht baheux dreiteilig klo...
# 5912  219 lime crush mc deppert ned marke akademie h...
# 5913  zistl initiative flchtlinge asylwerber kontakt...
# 5914  hietzing bchersonntag vhs austriaca bchersamml...
# 5915  music ikonika position bass club caf clubs cel...
#
#                      article_id
# 0     FALTER_201512234F1D30CEA9
# 1     FALTER_2015122382119EA87A
# 2     FALTER_2015122317D031535C
# 3     FALTER_20151223D853291AAA
# 4     FALTER_201512238A0DEB6E2D
# ...                         ...
# 5911  FALTER_20150114D1B1464B21
# 5912  FALTER_20150114100173AA99
# 5913  FALTER_201501144F8F9DDBEE
# 5914  FALTER_201501143FF6C01FA5
# 5915  FALTER_20150114D27133E690
#
# [5916 rows x 2 columns]

# %% [markdown]
# ### Embeddings and cosine similarity

# %%
open_file = open("../data/huggingface_embeddings.pkl", "rb")
hugging = pickle.load(open_file)
open_file.close()

# %%
open_file = open("../data/openaiembed.pkl", "rb")
openaiemb = pickle.load(open_file)
open_file.close()

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

def get_topk_similar_articles(embeddings, article_index, k, negativSimilartiy=False):
    """
    Get the top k news articles with highest similarity for a given index
    
    embeddings: embeddings matrix
    article_index: target article
    k = get the top k articles
    include_negative: if abs values should be used
    return top articles for given index
    """

    # Calculate pairwise cosine similarity with sklearn library
    similarity_scores = cosine_similarity(embeddings)
    
    # get similarity scores for the given article index
    article_scores = similarity_scores[article_index]
        
    # get negative similarity or positive ones
    # argsort returns the indices of the sorted array
    if negativSimilartiy:
        # [:k] to return only the top k article indices 
        sorted_indices = np.argsort(article_scores)[:k] 
    else:
        # [::-1] to order in decending order
        # 1:k+1 to exclude the target-article itself (similartiy = 1)
        sorted_indices = np.argsort(article_scores)[::-1][1:k+1] 
    
    # Get the top k (anti-) similar articles
    top_articles = [(index, article_scores[index]) for index in sorted_indices if index != article_index]
 
    return top_articles

# %%
# TEST Function with and without abs-values

target_article = 10
k = 5

# Get top similar articles for article at index 0
top_articles = get_topk_similar_articles(openaiemb, target_article, k, negativSimilartiy=False)

print(f"Top {k} Articles for Index: {target_article}:")
# Print the top similar articles
for article_index, similarity in top_articles:
    print(f"Article Index: {article_index}, Similarity Score: {similarity}")

    
    
# Get top anti-similar articles for article at index 0
top_articles = get_topk_similar_articles(openaiemb, target_article, k, negativSimilartiy=True)

print(f"\nTop {k} anti-similar Articles for Index: {target_article}:")
# Print the top similar articles
for article_index, similarity in top_articles:
    print(f"Article Index: {article_index}, Similarity Score: {similarity}")
# Out:
# Top 5 Articles for Index: 10:
# Article Index: 2864, Similarity Score: 0.9299139455903624
# Article Index: 1281, Similarity Score: 0.9241652057618484
# Article Index: 2565, Similarity Score: 0.922404355659658
# Article Index: 605, Similarity Score: 0.9189951849631544
# Article Index: 716, Similarity Score: 0.9187322475661385
#
# Top 5 anti-similar Articles for Index: 10:
# Article Index: 464, Similarity Score: 0.7503710360830974
# Article Index: 5812, Similarity Score: 0.7503710360830974
# Article Index: 115, Similarity Score: 0.7503710360830974
# Article Index: 4365, Similarity Score: 0.750375192310553
# Article Index: 1858, Similarity Score: 0.7503853669721208

# %%
target_article = 10
k = 5

# Get top similar articles for article at index 0
top_articles = get_topk_similar_articles(hugging, target_article, k, negativSimilartiy=False)

print(f"Top {k} Articles for Index: {target_article}:")
# Print the top similar articles
for article_index, similarity in top_articles:
    print(f"Article Index: {article_index}, Similarity Score: {similarity}")

    
    
# Get top anti-similar articles for article at index 0
top_articles = get_topk_similar_articles(hugging, target_article, k, negativSimilartiy=True)

print(f"\nTop {k} anti-similar Articles for Index: {target_article}:")
# Print the top similar articles
for article_index, similarity in top_articles:
    print(f"Article Index: {article_index}, Similarity Score: {similarity}")
# Out:
# Top 5 Articles for Index: 10:
# Article Index: 5646, Similarity Score: 0.8472929553617012
# Article Index: 4823, Similarity Score: 0.8272032157086442
# Article Index: 3896, Similarity Score: 0.822551773571327
# Article Index: 3464, Similarity Score: 0.8170489085814462
# Article Index: 2201, Similarity Score: 0.8016185365814101
#
# Top 5 anti-similar Articles for Index: 10:
# Article Index: 4379, Similarity Score: 0.02987027358264047
# Article Index: 1226, Similarity Score: 0.03661388581711076
# Article Index: 3717, Similarity Score: 0.04236515340781528
# Article Index: 1238, Similarity Score: 0.06198553187937104
# Article Index: 2961, Similarity Score: 0.06206713482469863

# %%
from langchain.embeddings import FakeEmbeddings
fakeemb = FakeEmbeddings(size=768)
embd = fakeemb.embed_documents(df_picked.Top_Words)

# %%
target_article = 10
k = 5

# Get top similar articles for article at index 0
top_articles = get_topk_similar_articles(embd, target_article, k, negativSimilartiy=False)

print(f"Top {k} Articles for Index: {target_article}:")
# Print the top similar articles
for article_index, similarity in top_articles:
    print(f"Article Index: {article_index}, Similarity Score: {similarity}")

    
    
# Get top anti-similar articles for article at index 0
top_articles = get_topk_similar_articles(embd, target_article, k, negativSimilartiy=True)

print(f"\nTop {k} anti-similar Articles for Index: {target_article}:")
# Print the top similar articles
for article_index, similarity in top_articles:
    print(f"Article Index: {article_index}, Similarity Score: {similarity}")
# Out:
# Top 5 Articles for Index: 10:
# Article Index: 4024, Similarity Score: 0.15125723880822828
# Article Index: 2348, Similarity Score: 0.14059374027199983
# Article Index: 1200, Similarity Score: 0.12434605278327526
# Article Index: 1242, Similarity Score: 0.11414544089612749
# Article Index: 5725, Similarity Score: 0.11394512766922134
#
# Top 5 anti-similar Articles for Index: 10:
# Article Index: 5776, Similarity Score: -0.12102506327488244
# Article Index: 3393, Similarity Score: -0.11952380853890138
# Article Index: 5356, Similarity Score: -0.11921368382470755
# Article Index: 2592, Similarity Score: -0.11344149219830721
# Article Index: 4767, Similarity Score: -0.11080571488958485

# %%
withsim = df_cleaned[~df_cleaned.Similarity.isna()]
withsim
# Out:
#                      article_id                              title  \
# 6     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 7     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 8     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 9     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 10    FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# ...                         ...                                ...
# 8298  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 8299  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 8300  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 8301  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 8302  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
#
#                                              paragraphs     ressort  \
# 6     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 7     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 8     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 9     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 10    ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# ...                                                 ...         ...
# 8298  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 8299  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 8300  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 8301  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 8302  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
#
#                   authors                       date  \
# 6          armin thurnher  2015-12-23 00:00:00+00:00
# 7          armin thurnher  2015-12-23 00:00:00+00:00
# 8          armin thurnher  2015-12-23 00:00:00+00:00
# 9          armin thurnher  2015-12-23 00:00:00+00:00
# 10         armin thurnher  2015-12-23 00:00:00+00:00
# ...                   ...                        ...
# 8298  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 8299  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 8300  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 8301  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 8302  sebastian fasthuber  2015-02-04 00:00:00+00:00
#
#                compared_article  Similarity
# 6     FALTER_2015011427A7C80584       0.875
# 7     FALTER_20151111C499C672CF       0.500
# 8     FALTER_20150513D7DA00D0E8       0.438
# 9     FALTER_2015120262C41042D2       0.312
# 10    FALTER_20150114EFB539A4D6       0.125
# ...                         ...         ...
# 8298  FALTER_201503113CDB7A5F2F      -0.292
# 8299  FALTER_2015040174B0CFCDBF      -0.333
# 8300  FALTER_20150715F62B384AE7      -0.417
# 8301  FALTER_20150408A2F8406B8A      -0.583
# 8302  FALTER_201506036534C38E6F      -0.958
#
# [2955 rows x 8 columns]

# %%
#withsim.join(df_picked, on="article_id", how="inner"joined=)
joined = withsim.merge(right=df_picked, how="left", on="article_id")
joined
# Out:
#                      article_id                              title  \
# 0     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 1     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 2     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 3     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 4     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# ...                         ...                                ...
# 2950  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2951  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2952  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2953  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2954  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
#
#                                              paragraphs     ressort  \
# 0     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 1     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 2     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 3     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 4     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# ...                                                 ...         ...
# 2950  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2951  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2952  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2953  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2954  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
#
#                   authors                       date  \
# 0          armin thurnher  2015-12-23 00:00:00+00:00
# 1          armin thurnher  2015-12-23 00:00:00+00:00
# 2          armin thurnher  2015-12-23 00:00:00+00:00
# 3          armin thurnher  2015-12-23 00:00:00+00:00
# 4          armin thurnher  2015-12-23 00:00:00+00:00
# ...                   ...                        ...
# 2950  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2951  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2952  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2953  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2954  sebastian fasthuber  2015-02-04 00:00:00+00:00
#
#                compared_article  Similarity  \
# 0     FALTER_2015011427A7C80584       0.875
# 1     FALTER_20151111C499C672CF       0.500
# 2     FALTER_20150513D7DA00D0E8       0.438
# 3     FALTER_2015120262C41042D2       0.312
# 4     FALTER_20150114EFB539A4D6       0.125
# ...                         ...         ...
# 2950  FALTER_201503113CDB7A5F2F      -0.292
# 2951  FALTER_2015040174B0CFCDBF      -0.333
# 2952  FALTER_20150715F62B384AE7      -0.417
# 2953  FALTER_20150408A2F8406B8A      -0.583
# 2954  FALTER_201506036534C38E6F      -0.958
#
#                                               Top_Words
# 0     journalismus ffentlichkeit lgenpresse medienja...
# 1     journalismus ffentlichkeit lgenpresse medienja...
# 2     journalismus ffentlichkeit lgenpresse medienja...
# 3     journalismus ffentlichkeit lgenpresse medienja...
# 4     journalismus ffentlichkeit lgenpresse medienja...
# ...                                                 ...
# 2950  geiger zwergflusspferd julian schriftsteller s...
# 2951  geiger zwergflusspferd julian schriftsteller s...
# 2952  geiger zwergflusspferd julian schriftsteller s...
# 2953  geiger zwergflusspferd julian schriftsteller s...
# 2954  geiger zwergflusspferd julian schriftsteller s...
#
# [2955 rows x 9 columns]

# %%
joined['class'] = pd.cut(joined['Similarity'], bins=[-1, -0.5, 0.5, 1], labels=[0, 1, 2], right=False)
joined
# Out:
#                      article_id                              title  \
# 0     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 1     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 2     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 3     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 4     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# ...                         ...                                ...
# 2950  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2951  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2952  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2953  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2954  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
#
#                                              paragraphs     ressort  \
# 0     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 1     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 2     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 3     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 4     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# ...                                                 ...         ...
# 2950  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2951  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2952  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2953  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2954  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
#
#                   authors                       date  \
# 0          armin thurnher  2015-12-23 00:00:00+00:00
# 1          armin thurnher  2015-12-23 00:00:00+00:00
# 2          armin thurnher  2015-12-23 00:00:00+00:00
# 3          armin thurnher  2015-12-23 00:00:00+00:00
# 4          armin thurnher  2015-12-23 00:00:00+00:00
# ...                   ...                        ...
# 2950  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2951  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2952  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2953  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2954  sebastian fasthuber  2015-02-04 00:00:00+00:00
#
#                compared_article  Similarity  \
# 0     FALTER_2015011427A7C80584       0.875
# 1     FALTER_20151111C499C672CF       0.500
# 2     FALTER_20150513D7DA00D0E8       0.438
# 3     FALTER_2015120262C41042D2       0.312
# 4     FALTER_20150114EFB539A4D6       0.125
# ...                         ...         ...
# 2950  FALTER_201503113CDB7A5F2F      -0.292
# 2951  FALTER_2015040174B0CFCDBF      -0.333
# 2952  FALTER_20150715F62B384AE7      -0.417
# 2953  FALTER_20150408A2F8406B8A      -0.583
# 2954  FALTER_201506036534C38E6F      -0.958
#
#                                               Top_Words class
# 0     journalismus ffentlichkeit lgenpresse medienja...     2
# 1     journalismus ffentlichkeit lgenpresse medienja...     2
# 2     journalismus ffentlichkeit lgenpresse medienja...     1
# 3     journalismus ffentlichkeit lgenpresse medienja...     1
# 4     journalismus ffentlichkeit lgenpresse medienja...     1
# ...                                                 ...   ...
# 2950  geiger zwergflusspferd julian schriftsteller s...     1
# 2951  geiger zwergflusspferd julian schriftsteller s...     1
# 2952  geiger zwergflusspferd julian schriftsteller s...     1
# 2953  geiger zwergflusspferd julian schriftsteller s...     0
# 2954  geiger zwergflusspferd julian schriftsteller s...     0
#
# [2955 rows x 10 columns]

# %%
comp_list = []
for i in joined.compared_article:
    
    comp_list.append(demo[demo.article_id == i]["title"].values[0])
joined["compared_article_title"] = comp_list

# %%
joined
# Out:
#                      article_id                              title  \
# 0     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 1     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 2     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 3     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 4     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# ...                         ...                                ...
# 2950  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2951  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2952  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2953  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2954  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
#
#                                              paragraphs     ressort  \
# 0     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 1     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 2     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 3     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 4     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# ...                                                 ...         ...
# 2950  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2951  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2952  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2953  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2954  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
#
#                   authors                       date  \
# 0          armin thurnher  2015-12-23 00:00:00+00:00
# 1          armin thurnher  2015-12-23 00:00:00+00:00
# 2          armin thurnher  2015-12-23 00:00:00+00:00
# 3          armin thurnher  2015-12-23 00:00:00+00:00
# 4          armin thurnher  2015-12-23 00:00:00+00:00
# ...                   ...                        ...
# 2950  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2951  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2952  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2953  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2954  sebastian fasthuber  2015-02-04 00:00:00+00:00
#
#                compared_article  Similarity  \
# 0     FALTER_2015011427A7C80584       0.875
# 1     FALTER_20151111C499C672CF       0.500
# 2     FALTER_20150513D7DA00D0E8       0.438
# 3     FALTER_2015120262C41042D2       0.312
# 4     FALTER_20150114EFB539A4D6       0.125
# ...                         ...         ...
# 2950  FALTER_201503113CDB7A5F2F      -0.292
# 2951  FALTER_2015040174B0CFCDBF      -0.333
# 2952  FALTER_20150715F62B384AE7      -0.417
# 2953  FALTER_20150408A2F8406B8A      -0.583
# 2954  FALTER_201506036534C38E6F      -0.958
#
#                                               Top_Words class  \
# 0     journalismus ffentlichkeit lgenpresse medienja...     2
# 1     journalismus ffentlichkeit lgenpresse medienja...     2
# 2     journalismus ffentlichkeit lgenpresse medienja...     1
# 3     journalismus ffentlichkeit lgenpresse medienja...     1
# 4     journalismus ffentlichkeit lgenpresse medienja...     1
# ...                                                 ...   ...
# 2950  geiger zwergflusspferd julian schriftsteller s...     1
# 2951  geiger zwergflusspferd julian schriftsteller s...     1
# 2952  geiger zwergflusspferd julian schriftsteller s...     1
# 2953  geiger zwergflusspferd julian schriftsteller s...     0
# 2954  geiger zwergflusspferd julian schriftsteller s...     0
#
#                                  compared_article_title
# 0                             Groß geworden mit Charlie
# 1                  Zampano Murdoch verliert Werbeerlöse
# 2     Wahlen in Großbritannien. Willkommen in der Me...
# 3                            Aus privat mach öffentlich
# 4     Die Islam-Falle: It's not islam, it's religion...
# ...                                                 ...
# 2950                        Acht Jahre ohne Schwerkraft
# 2951                            Die Neue vom News-Tower
# 2952                                     OLLAS LEIWAUND
# 2953             Ich suchte Gott. Also wurde ich Muslim
# 2954                               Mein verlorener Sohn
#
# [2955 rows x 11 columns]

# %%
joined.to_csv("../data/joinec.csv", index=False)

# %%
fakeemb = FakeEmbeddings(size=100)
mappings = {}
for i in joined.article_id.unique():
    joined[joined.article_id == i]
    embd = fakeemb.embed_documents(joined[joined.article_id == i].iloc[0].Top_Words)
    mappings[i] = embd

# %% [markdown]
# ## GETTOP80 words from targetarticle and compared one then concat the text. TFIDF and fit in Logistic regression

# %% [markdown]
# ### Classificaiton problem and how it should be evaluated ???

# %%
np.array(mappings["FALTER_201512234A05C075C5"]).shape
# Out:
# (727, 100)

# %%
np.array(openaiemb).shape
# Out:
# (5916, 1536)

# %%
joined
# Out:
#                      article_id                              title  \
# 0     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 1     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 2     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 3     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 4     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# ...                         ...                                ...
# 2950  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2951  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2952  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2953  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2954  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
#
#                                              paragraphs     ressort  \
# 0     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 1     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 2     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 3     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 4     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# ...                                                 ...         ...
# 2950  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2951  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2952  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2953  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2954  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
#
#                   authors                       date  \
# 0          armin thurnher  2015-12-23 00:00:00+00:00
# 1          armin thurnher  2015-12-23 00:00:00+00:00
# 2          armin thurnher  2015-12-23 00:00:00+00:00
# 3          armin thurnher  2015-12-23 00:00:00+00:00
# 4          armin thurnher  2015-12-23 00:00:00+00:00
# ...                   ...                        ...
# 2950  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2951  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2952  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2953  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2954  sebastian fasthuber  2015-02-04 00:00:00+00:00
#
#                compared_article  Similarity  \
# 0     FALTER_2015011427A7C80584       0.875
# 1     FALTER_20151111C499C672CF       0.500
# 2     FALTER_20150513D7DA00D0E8       0.438
# 3     FALTER_2015120262C41042D2       0.312
# 4     FALTER_20150114EFB539A4D6       0.125
# ...                         ...         ...
# 2950  FALTER_201503113CDB7A5F2F      -0.292
# 2951  FALTER_2015040174B0CFCDBF      -0.333
# 2952  FALTER_20150715F62B384AE7      -0.417
# 2953  FALTER_20150408A2F8406B8A      -0.583
# 2954  FALTER_201506036534C38E6F      -0.958
#
#                                               Top_Words class  \
# 0     journalismus ffentlichkeit lgenpresse medienja...     2
# 1     journalismus ffentlichkeit lgenpresse medienja...     2
# 2     journalismus ffentlichkeit lgenpresse medienja...     1
# 3     journalismus ffentlichkeit lgenpresse medienja...     1
# 4     journalismus ffentlichkeit lgenpresse medienja...     1
# ...                                                 ...   ...
# 2950  geiger zwergflusspferd julian schriftsteller s...     1
# 2951  geiger zwergflusspferd julian schriftsteller s...     1
# 2952  geiger zwergflusspferd julian schriftsteller s...     1
# 2953  geiger zwergflusspferd julian schriftsteller s...     0
# 2954  geiger zwergflusspferd julian schriftsteller s...     0
#
#                                  compared_article_title
# 0                             Groß geworden mit Charlie
# 1                  Zampano Murdoch verliert Werbeerlöse
# 2     Wahlen in Großbritannien. Willkommen in der Me...
# 3                            Aus privat mach öffentlich
# 4     Die Islam-Falle: It's not islam, it's religion...
# ...                                                 ...
# 2950                        Acht Jahre ohne Schwerkraft
# 2951                            Die Neue vom News-Tower
# 2952                                     OLLAS LEIWAUND
# 2953             Ich suchte Gott. Also wurde ich Muslim
# 2954                               Mein verlorener Sohn
#
# [2955 rows x 11 columns]

# %%
demo
# Out:
#                      article_id  \
# 0     FALTER_201512234F1D30CEA9
# 1     FALTER_2015122382119EA87A
# 2     FALTER_2015122317D031535C
# 3     FALTER_20151223D853291AAA
# 4     FALTER_201512238A0DEB6E2D
# ...                         ...
# 5911  FALTER_20150114D1B1464B21
# 5912  FALTER_20150114100173AA99
# 5913  FALTER_201501144F8F9DDBEE
# 5914  FALTER_201501143FF6C01FA5
# 5915  FALTER_20150114D27133E690
#
#                                                   title  \
# 0                    "Bewundere Frau Merkel über alles"
# 1                                           Wildbretter
# 2     Warum es ganz normal sein kann, zwei Zuhause z...
# 3                                      Der Lerchenfisch
# 4                      Uhudler-Orbán und Kernölamazonen
# ...                                                 ...
# 5911             Achte Ausgabe des Festivals in between
# 5912             Punkrock der Marke "Ned deppert sein!"
# 5913  Mit einem Flüchtling in der WG: Neue Initiativ...
# 5914                          Büchersonntag in Hietzing
# 5915  Neuer Floor, neue Party: ein guter Start ins P...
#
#                                              paragraphs      ressort  \
# 0     ['Kinderwagen drängen sich bei der Eingangstür...   Steiermark
# 1     ['Das Handbuch der Kolumnenschreiberei sieht v...  Falters Zoo
# 2     ['Xenia, Fotografin, 22', 'Ich habe bis vor zw...   Stadtleben
# 3     ['Zuerst Korrektur eines Irrtums: Nicht die AM...   Stadtleben
# 4     ['Wann feiert ein Kabarettist eigentlich Silve...      Lexikon
# ...                                                 ...          ...
# 5911  ['Das Konzept ist so einfach wie schlüssig: Zu...      Lexikon
# 5912  ['Drei Songs in viereinhalb Minuten: Lime Crus...      Lexikon
# 5913  ['Warum müssen Menschen, die vor Krieg und Ele...      Politik
# 5914  ['Sammler sind Getriebene, das gilt auch für B...      Lexikon
# 5915  ['Die Kickdrum zischt und dampft, die Snares r...      Lexikon
#
#                                      authors                       date  \
# 0                           gerlinde pölsler  2015-12-23 00:00:00+00:00
# 1                                        NaN  2015-12-23 00:00:00+00:00
# 2                               barbara tóth  2015-12-23 00:00:00+00:00
# 3                             florian holzer  2015-12-23 00:00:00+00:00
# 4     stefanie panzenböck, sara schausberger  2015-12-23 00:00:00+00:00
# ...                                      ...                        ...
# 5911                                      gs  2015-01-14 00:00:00+00:00
# 5912                                     NaN  2015-01-14 00:00:00+00:00
# 5913                  benedikt narodoslawsky  2015-01-14 00:00:00+00:00
# 5914                                     NaN  2015-01-14 00:00:00+00:00
# 5915                       katharina seidler  2015-01-14 00:00:00+00:00
#
#                                            text_cleaned
# 0     kinderwagen drngen eingangstr wolfgang puchers...
# 1     handbuch kolumnenschreiberei sieht letzte glos...
# 2     xenia fotografin 22 zwei jahren tag zuhause ge...
# 3     zuerst korrektur irrtums ama betrieb restauran...
# 4     wann feiert kabarettist eigentlich silvester a...
# ...                                                 ...
# 5911  konzept einfach schlssig zugereiste wiener mus...
# 5912  drei songs viereinhalb minuten lime crush setz...
# 5913  warum mssen menschen krieg elend flchten masse...
# 5914  sammler getriebene gilt fr bchersammler seit 1...
# 5915  kickdrum zischt dampft snares rollen triolen h...
#
# [5916 rows x 7 columns]

# %%
demo["openai_emb"] = openaiemb

# %%
gotten_text = []
target_article_embed = []
comparedartic_embed = []

for i in range(joined.shape[0]):
    target_id = joined.loc[i, "article_id"]
    
    compared_id = joined.loc[i, "compared_article"]
    
    gotten_text.append(demo[demo.article_id == target_id]["text_cleaned"].values[0] + " " + demo[demo.article_id == compared_id]["text_cleaned"].values[0])
    target_article_embed.append(demo[demo.article_id == target_id]["openai_emb"].values[0])
    comparedartic_embed.append(demo[demo.article_id == compared_id]["openai_emb"].values[0])
    
    
joined["combined_text"] = gotten_text
joined["target_embeddings"] = target_article_embed
joined["compared_embeddings"] = comparedartic_embed

# %%
joined["class"] = joined["class"].fillna(1.0)

# %%
joined["class"].value_counts()
# Out:
# 1    2315
# 2     338
# 0     302
# Name: class, dtype: int64

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(joined["combined_text"])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(tfidf_matrix, joined["class"], test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# Initialize the logistic regression classifier
classifier = LogisticRegression()
svm = SVC()
forest = RandomForestClassifier(n_estimators=300)

# Train the model
forest.fit(X_train, y_train)

# Evaluate the model
accuracy = forest.score(X_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.754653130287648

# %%
y_pred = forest.predict(X_test)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Assuming you have predicted labels (y_pred) and true labels (y_true)
# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Define class labels (if available)
class_labels = ['Class 0', 'Class 1', 'Class 2']

# Create a heatmap of the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d', xticklabels=class_labels, yticklabels=class_labels)

# Add labels, title, and axis ticks
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.xticks(np.arange(len(class_labels)) + 0.5, class_labels)
plt.yticks(np.arange(len(class_labels)) + 0.5, class_labels)

# Show the plot
plt.show()

# %%
joined['class_rediced'] = pd.cut(joined['Similarity'], bins=[-1, 0.2, 1.5], labels=[0, 1], right=False)
joined
# Out:
#                      article_id                              title  \
# 0     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 1     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 2     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 3     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 4     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# ...                         ...                                ...
# 2950  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2951  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2952  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2953  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2954  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
#
#                                              paragraphs     ressort  \
# 0     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 1     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 2     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 3     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 4     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# ...                                                 ...         ...
# 2950  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2951  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2952  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2953  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2954  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
#
#                   authors                       date  \
# 0          armin thurnher  2015-12-23 00:00:00+00:00
# 1          armin thurnher  2015-12-23 00:00:00+00:00
# 2          armin thurnher  2015-12-23 00:00:00+00:00
# 3          armin thurnher  2015-12-23 00:00:00+00:00
# 4          armin thurnher  2015-12-23 00:00:00+00:00
# ...                   ...                        ...
# 2950  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2951  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2952  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2953  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2954  sebastian fasthuber  2015-02-04 00:00:00+00:00
#
#                compared_article  Similarity  \
# 0     FALTER_2015011427A7C80584       0.875
# 1     FALTER_20151111C499C672CF       0.500
# 2     FALTER_20150513D7DA00D0E8       0.438
# 3     FALTER_2015120262C41042D2       0.312
# 4     FALTER_20150114EFB539A4D6       0.125
# ...                         ...         ...
# 2950  FALTER_201503113CDB7A5F2F      -0.292
# 2951  FALTER_2015040174B0CFCDBF      -0.333
# 2952  FALTER_20150715F62B384AE7      -0.417
# 2953  FALTER_20150408A2F8406B8A      -0.583
# 2954  FALTER_201506036534C38E6F      -0.958
#
#                                               Top_Words class  \
# 0     journalismus ffentlichkeit lgenpresse medienja...     2
# 1     journalismus ffentlichkeit lgenpresse medienja...     2
# 2     journalismus ffentlichkeit lgenpresse medienja...     1
# 3     journalismus ffentlichkeit lgenpresse medienja...     1
# 4     journalismus ffentlichkeit lgenpresse medienja...     1
# ...                                                 ...   ...
# 2950  geiger zwergflusspferd julian schriftsteller s...     1
# 2951  geiger zwergflusspferd julian schriftsteller s...     1
# 2952  geiger zwergflusspferd julian schriftsteller s...     1
# 2953  geiger zwergflusspferd julian schriftsteller s...     0
# 2954  geiger zwergflusspferd julian schriftsteller s...     0
#
#                                  compared_article_title  \
# 0                             Groß geworden mit Charlie
# 1                  Zampano Murdoch verliert Werbeerlöse
# 2     Wahlen in Großbritannien. Willkommen in der Me...
# 3                            Aus privat mach öffentlich
# 4     Die Islam-Falle: It's not islam, it's religion...
# ...                                                 ...
# 2950                        Acht Jahre ohne Schwerkraft
# 2951                            Die Neue vom News-Tower
# 2952                                     OLLAS LEIWAUND
# 2953             Ich suchte Gott. Also wurde ich Muslim
# 2954                               Mein verlorener Sohn
#
#                                           combined_text  \
# 0     medienjahr bilanzieren attentat charlie hebdo ...
# 1     medienjahr bilanzieren attentat charlie hebdo ...
# 2     medienjahr bilanzieren attentat charlie hebdo ...
# 3     medienjahr bilanzieren attentat charlie hebdo ...
# 4     medienjahr bilanzieren attentat charlie hebdo ...
# ...                                                 ...
# 2950  bestsellerautoren zeichnen gewhnlich zurckhalt...
# 2951  bestsellerautoren zeichnen gewhnlich zurckhalt...
# 2952  bestsellerautoren zeichnen gewhnlich zurckhalt...
# 2953  bestsellerautoren zeichnen gewhnlich zurckhalt...
# 2954  bestsellerautoren zeichnen gewhnlich zurckhalt...
#
#                                       target_embeddings  \
# 0     [0.0035209779636490813, 0.01821752662176953, 0...
# 1     [0.0035209779636490813, 0.01821752662176953, 0...
# 2     [0.0035209779636490813, 0.01821752662176953, 0...
# 3     [0.0035209779636490813, 0.01821752662176953, 0...
# 4     [0.0035209779636490813, 0.01821752662176953, 0...
# ...                                                 ...
# 2950  [-0.008657581413388906, 0.011235555946023417, ...
# 2951  [-0.008657581413388906, 0.011235555946023417, ...
# 2952  [-0.008657581413388906, 0.011235555946023417, ...
# 2953  [-0.008657581413388906, 0.011235555946023417, ...
# 2954  [-0.008657581413388906, 0.011235555946023417, ...
#
#                                     compared_embeddings class_rediced
# 0     [0.007898138161386938, -0.00038673470937219045...             1
# 1     [-0.01676557060042422, -0.005943669589727185, ...             1
# 2     [-0.0009496021375325843, -0.006033560911583878...             1
# 3     [-0.0010888515102154151, -0.008951110076284316...             1
# 4     [-0.0021449944946193137, -0.010719971969251821...             0
# ...                                                 ...           ...
# 2950  [-0.0023891259487316624, -0.003109848536613519...             0
# 2951  [0.009311860085706607, -0.006618989388752813, ...             0
# 2952  [-0.007847336641682991, -0.009044619735261796,...             0
# 2953  [-0.006227686327747443, 0.0023753562528619895,...             0
# 2954  [-0.005173245725986526, 0.005597226160165973, ...             0
#
# [2955 rows x 15 columns]

# %%
joined.class_rediced.value_counts()
# Out:
# 0    2028
# 1     927
# Name: class_rediced, dtype: int64

# %%
X_train_red, X_test_red, y_train_red, y_test_red = train_test_split(tfidf_matrix, joined["class_rediced"], test_size=0.2, random_state=42)

# %%
classifier = LogisticRegression()
svm = SVC()
forest = RandomForestClassifier(n_estimators=300)

# Train the model
forest.fit(X_train_red, y_train_red)

# Evaluate the model
accuracy = forest.score(X_test_red, y_test_red)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6717428087986463

# %%
y_pred = forest.predict(X_test_red)

# Assuming you have predicted labels (y_pred) and true labels (y_true)
# Compute the confusion matrix
cm = confusion_matrix(y_test_red, y_pred)

# Define class labels (if available)
class_labels = ['Class 0', 'Class 1']

# Create a heatmap of the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d', xticklabels=class_labels, yticklabels=class_labels)

# Add labels, title, and axis ticks
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.xticks(np.arange(len(class_labels)) + 0.5, class_labels)
plt.yticks(np.arange(len(class_labels)) + 0.5, class_labels)

# Show the plot
plt.show()

# %%
joined
# Out:
#                      article_id                              title  \
# 0     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 1     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 2     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 3     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 4     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# ...                         ...                                ...
# 2950  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2951  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2952  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2953  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2954  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
#
#                                              paragraphs     ressort  \
# 0     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 1     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 2     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 3     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 4     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# ...                                                 ...         ...
# 2950  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2951  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2952  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2953  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2954  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
#
#                   authors                       date  \
# 0          armin thurnher  2015-12-23 00:00:00+00:00
# 1          armin thurnher  2015-12-23 00:00:00+00:00
# 2          armin thurnher  2015-12-23 00:00:00+00:00
# 3          armin thurnher  2015-12-23 00:00:00+00:00
# 4          armin thurnher  2015-12-23 00:00:00+00:00
# ...                   ...                        ...
# 2950  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2951  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2952  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2953  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2954  sebastian fasthuber  2015-02-04 00:00:00+00:00
#
#                compared_article  Similarity  \
# 0     FALTER_2015011427A7C80584       0.875
# 1     FALTER_20151111C499C672CF       0.500
# 2     FALTER_20150513D7DA00D0E8       0.438
# 3     FALTER_2015120262C41042D2       0.312
# 4     FALTER_20150114EFB539A4D6       0.125
# ...                         ...         ...
# 2950  FALTER_201503113CDB7A5F2F      -0.292
# 2951  FALTER_2015040174B0CFCDBF      -0.333
# 2952  FALTER_20150715F62B384AE7      -0.417
# 2953  FALTER_20150408A2F8406B8A      -0.583
# 2954  FALTER_201506036534C38E6F      -0.958
#
#                                               Top_Words class  \
# 0     journalismus ffentlichkeit lgenpresse medienja...     2
# 1     journalismus ffentlichkeit lgenpresse medienja...     2
# 2     journalismus ffentlichkeit lgenpresse medienja...     1
# 3     journalismus ffentlichkeit lgenpresse medienja...     1
# 4     journalismus ffentlichkeit lgenpresse medienja...     1
# ...                                                 ...   ...
# 2950  geiger zwergflusspferd julian schriftsteller s...     1
# 2951  geiger zwergflusspferd julian schriftsteller s...     1
# 2952  geiger zwergflusspferd julian schriftsteller s...     1
# 2953  geiger zwergflusspferd julian schriftsteller s...     0
# 2954  geiger zwergflusspferd julian schriftsteller s...     0
#
#                                  compared_article_title  \
# 0                             Groß geworden mit Charlie
# 1                  Zampano Murdoch verliert Werbeerlöse
# 2     Wahlen in Großbritannien. Willkommen in der Me...
# 3                            Aus privat mach öffentlich
# 4     Die Islam-Falle: It's not islam, it's religion...
# ...                                                 ...
# 2950                        Acht Jahre ohne Schwerkraft
# 2951                            Die Neue vom News-Tower
# 2952                                     OLLAS LEIWAUND
# 2953             Ich suchte Gott. Also wurde ich Muslim
# 2954                               Mein verlorener Sohn
#
#                                           combined_text  \
# 0     medienjahr bilanzieren attentat charlie hebdo ...
# 1     medienjahr bilanzieren attentat charlie hebdo ...
# 2     medienjahr bilanzieren attentat charlie hebdo ...
# 3     medienjahr bilanzieren attentat charlie hebdo ...
# 4     medienjahr bilanzieren attentat charlie hebdo ...
# ...                                                 ...
# 2950  bestsellerautoren zeichnen gewhnlich zurckhalt...
# 2951  bestsellerautoren zeichnen gewhnlich zurckhalt...
# 2952  bestsellerautoren zeichnen gewhnlich zurckhalt...
# 2953  bestsellerautoren zeichnen gewhnlich zurckhalt...
# 2954  bestsellerautoren zeichnen gewhnlich zurckhalt...
#
#                                       target_embeddings  \
# 0     [0.0035209779636490813, 0.01821752662176953, 0...
# 1     [0.0035209779636490813, 0.01821752662176953, 0...
# 2     [0.0035209779636490813, 0.01821752662176953, 0...
# 3     [0.0035209779636490813, 0.01821752662176953, 0...
# 4     [0.0035209779636490813, 0.01821752662176953, 0...
# ...                                                 ...
# 2950  [-0.008657581413388906, 0.011235555946023417, ...
# 2951  [-0.008657581413388906, 0.011235555946023417, ...
# 2952  [-0.008657581413388906, 0.011235555946023417, ...
# 2953  [-0.008657581413388906, 0.011235555946023417, ...
# 2954  [-0.008657581413388906, 0.011235555946023417, ...
#
#                                     compared_embeddings class_rediced
# 0     [0.007898138161386938, -0.00038673470937219045...             1
# 1     [-0.01676557060042422, -0.005943669589727185, ...             1
# 2     [-0.0009496021375325843, -0.006033560911583878...             1
# 3     [-0.0010888515102154151, -0.008951110076284316...             1
# 4     [-0.0021449944946193137, -0.010719971969251821...             0
# ...                                                 ...           ...
# 2950  [-0.0023891259487316624, -0.003109848536613519...             0
# 2951  [0.009311860085706607, -0.006618989388752813, ...             0
# 2952  [-0.007847336641682991, -0.009044619735261796,...             0
# 2953  [-0.006227686327747443, 0.0023753562528619895,...             0
# 2954  [-0.005173245725986526, 0.005597226160165973, ...             0
#
# [2955 rows x 15 columns]

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Define the model architecture
model = Sequential()
model.add(Dense(64, input_shape=(1536,), activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(2, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print the summary of the model
model.summary()
# Out:
# 2023-07-09 14:34:23.275206: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                98368
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 100,514
# Trainable params: 100,514
# Non-trainable params: 0
# _________________________________________________________________

# %%
#joined["combined_Embeddings"] = pd.concat([joined.target_embeddings, joined.compared_embeddings], axis=0, ignore_index=True)

# %%
joined
# Out:
#                      article_id                              title  \
# 0     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 1     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 2     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 3     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 4     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# ...                         ...                                ...
# 2950  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2951  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2952  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2953  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2954  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
#
#                                              paragraphs     ressort  \
# 0     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 1     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 2     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 3     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 4     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# ...                                                 ...         ...
# 2950  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2951  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2952  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2953  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2954  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
#
#                   authors                       date  \
# 0          armin thurnher  2015-12-23 00:00:00+00:00
# 1          armin thurnher  2015-12-23 00:00:00+00:00
# 2          armin thurnher  2015-12-23 00:00:00+00:00
# 3          armin thurnher  2015-12-23 00:00:00+00:00
# 4          armin thurnher  2015-12-23 00:00:00+00:00
# ...                   ...                        ...
# 2950  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2951  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2952  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2953  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2954  sebastian fasthuber  2015-02-04 00:00:00+00:00
#
#                compared_article  Similarity  \
# 0     FALTER_2015011427A7C80584       0.875
# 1     FALTER_20151111C499C672CF       0.500
# 2     FALTER_20150513D7DA00D0E8       0.438
# 3     FALTER_2015120262C41042D2       0.312
# 4     FALTER_20150114EFB539A4D6       0.125
# ...                         ...         ...
# 2950  FALTER_201503113CDB7A5F2F      -0.292
# 2951  FALTER_2015040174B0CFCDBF      -0.333
# 2952  FALTER_20150715F62B384AE7      -0.417
# 2953  FALTER_20150408A2F8406B8A      -0.583
# 2954  FALTER_201506036534C38E6F      -0.958
#
#                                               Top_Words class  \
# 0     journalismus ffentlichkeit lgenpresse medienja...     2
# 1     journalismus ffentlichkeit lgenpresse medienja...     2
# 2     journalismus ffentlichkeit lgenpresse medienja...     1
# 3     journalismus ffentlichkeit lgenpresse medienja...     1
# 4     journalismus ffentlichkeit lgenpresse medienja...     1
# ...                                                 ...   ...
# 2950  geiger zwergflusspferd julian schriftsteller s...     1
# 2951  geiger zwergflusspferd julian schriftsteller s...     1
# 2952  geiger zwergflusspferd julian schriftsteller s...     1
# 2953  geiger zwergflusspferd julian schriftsteller s...     0
# 2954  geiger zwergflusspferd julian schriftsteller s...     0
#
#                                  compared_article_title  \
# 0                             Groß geworden mit Charlie
# 1                  Zampano Murdoch verliert Werbeerlöse
# 2     Wahlen in Großbritannien. Willkommen in der Me...
# 3                            Aus privat mach öffentlich
# 4     Die Islam-Falle: It's not islam, it's religion...
# ...                                                 ...
# 2950                        Acht Jahre ohne Schwerkraft
# 2951                            Die Neue vom News-Tower
# 2952                                     OLLAS LEIWAUND
# 2953             Ich suchte Gott. Also wurde ich Muslim
# 2954                               Mein verlorener Sohn
#
#                                           combined_text  \
# 0     medienjahr bilanzieren attentat charlie hebdo ...
# 1     medienjahr bilanzieren attentat charlie hebdo ...
# 2     medienjahr bilanzieren attentat charlie hebdo ...
# 3     medienjahr bilanzieren attentat charlie hebdo ...
# 4     medienjahr bilanzieren attentat charlie hebdo ...
# ...                                                 ...
# 2950  bestsellerautoren zeichnen gewhnlich zurckhalt...
# 2951  bestsellerautoren zeichnen gewhnlich zurckhalt...
# 2952  bestsellerautoren zeichnen gewhnlich zurckhalt...
# 2953  bestsellerautoren zeichnen gewhnlich zurckhalt...
# 2954  bestsellerautoren zeichnen gewhnlich zurckhalt...
#
#                                       target_embeddings  \
# 0     [0.0035209779636490813, 0.01821752662176953, 0...
# 1     [0.0035209779636490813, 0.01821752662176953, 0...
# 2     [0.0035209779636490813, 0.01821752662176953, 0...
# 3     [0.0035209779636490813, 0.01821752662176953, 0...
# 4     [0.0035209779636490813, 0.01821752662176953, 0...
# ...                                                 ...
# 2950  [-0.008657581413388906, 0.011235555946023417, ...
# 2951  [-0.008657581413388906, 0.011235555946023417, ...
# 2952  [-0.008657581413388906, 0.011235555946023417, ...
# 2953  [-0.008657581413388906, 0.011235555946023417, ...
# 2954  [-0.008657581413388906, 0.011235555946023417, ...
#
#                                     compared_embeddings class_rediced
# 0     [0.007898138161386938, -0.00038673470937219045...             1
# 1     [-0.01676557060042422, -0.005943669589727185, ...             1
# 2     [-0.0009496021375325843, -0.006033560911583878...             1
# 3     [-0.0010888515102154151, -0.008951110076284316...             1
# 4     [-0.0021449944946193137, -0.010719971969251821...             0
# ...                                                 ...           ...
# 2950  [-0.0023891259487316624, -0.003109848536613519...             0
# 2951  [0.009311860085706607, -0.006618989388752813, ...             0
# 2952  [-0.007847336641682991, -0.009044619735261796,...             0
# 2953  [-0.006227686327747443, 0.0023753562528619895,...             0
# 2954  [-0.005173245725986526, 0.005597226160165973, ...             0
#
# [2955 rows x 15 columns]

# %%
from sklearn.linear_model import Ridge, LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(tfidf_matrix, joined["Similarity"], test_size=0.2, random_state=42)

# %%
rid = LinearRegression()

# %%
rid.fit(X_train_reg, y_train_reg)
# Out:
# LinearRegression()

# %%
rid.score(X_test_reg, y_test_reg)
# Out:
# -0.6209402106873148

# %%
preds = rid.predict(X_test_reg)
mean_absolute_error(preds, y_test_reg)
# Out:
# 0.38502358541792947

# %%
mean_squared_error(preds, y_test_reg)
# Out:
# 0.25559178370502017

# %%
preds[2]
# Out:
# 0.04930946643152412

# %%
y_test_reg.iloc[2]
# Out:
# -0.208

# %% [markdown]
# ## OPENAI

# %%
output_file = 'output.jsonl'

# %%
with open(output_file, 'w') as f:
    for index, row in joined.iterrows():
        if(row.Similarity >= 0.5):
            para = row.Top_Words + "\n\n###\n\n"
            compared = "Der Artikel ist ähnlich wie der angegebene: " + row.compared_article_title + " \n"
        elif(row.Similarity <= -0.5):
            para = row.Top_Words + "\n\n###\n\n"
            compared = "Der folgende Artikel sollte nicht empfohlen werden: " + row.compared_article_title + " \n"
        else:
            para = row.Top_Words + "\n\n###\n\n"
            compared = "Der folgende Artikel ist neutral: " + row.compared_article_title + " \n"
        row_dict = {
            "prompt": para,
            "completion": compared
        }
        json.dump(row_dict, f)
        f.write('\n')

# %%
joined
# Out:
#                      article_id                              title  \
# 0     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 1     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 2     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 3     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# 4     FALTER_201512234A05C075C5  Die Wahrheit über die Lügenpresse
# ...                         ...                                ...
# 2950  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2951  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2952  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2953  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
# 2954  FALTER_201502043AFFDEA0E6             "Es geht um Befreiung"
#
#                                              paragraphs     ressort  \
# 0     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 1     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 2     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 3     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# 4     ['Also, wie soll man ein Medienjahr bilanziere...      Medien
# ...                                                 ...         ...
# 2950  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2951  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2952  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2953  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
# 2954  ['Bestsellerautoren zeichnen sich gewöhnlich n...  Feuilleton
#
#                   authors                       date  \
# 0          armin thurnher  2015-12-23 00:00:00+00:00
# 1          armin thurnher  2015-12-23 00:00:00+00:00
# 2          armin thurnher  2015-12-23 00:00:00+00:00
# 3          armin thurnher  2015-12-23 00:00:00+00:00
# 4          armin thurnher  2015-12-23 00:00:00+00:00
# ...                   ...                        ...
# 2950  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2951  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2952  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2953  sebastian fasthuber  2015-02-04 00:00:00+00:00
# 2954  sebastian fasthuber  2015-02-04 00:00:00+00:00
#
#                compared_article  Similarity  \
# 0     FALTER_2015011427A7C80584       0.875
# 1     FALTER_20151111C499C672CF       0.500
# 2     FALTER_20150513D7DA00D0E8       0.438
# 3     FALTER_2015120262C41042D2       0.312
# 4     FALTER_20150114EFB539A4D6       0.125
# ...                         ...         ...
# 2950  FALTER_201503113CDB7A5F2F      -0.292
# 2951  FALTER_2015040174B0CFCDBF      -0.333
# 2952  FALTER_20150715F62B384AE7      -0.417
# 2953  FALTER_20150408A2F8406B8A      -0.583
# 2954  FALTER_201506036534C38E6F      -0.958
#
#                                               Top_Words class  \
# 0     journalismus ffentlichkeit lgenpresse medienja...     2
# 1     journalismus ffentlichkeit lgenpresse medienja...     2
# 2     journalismus ffentlichkeit lgenpresse medienja...     1
# 3     journalismus ffentlichkeit lgenpresse medienja...     1
# 4     journalismus ffentlichkeit lgenpresse medienja...     1
# ...                                                 ...   ...
# 2950  geiger zwergflusspferd julian schriftsteller s...     1
# 2951  geiger zwergflusspferd julian schriftsteller s...     1
# 2952  geiger zwergflusspferd julian schriftsteller s...     1
# 2953  geiger zwergflusspferd julian schriftsteller s...     0
# 2954  geiger zwergflusspferd julian schriftsteller s...     0
#
#                                  compared_article_title
# 0                             Groß geworden mit Charlie
# 1                  Zampano Murdoch verliert Werbeerlöse
# 2     Wahlen in Großbritannien. Willkommen in der Me...
# 3                            Aus privat mach öffentlich
# 4     Die Islam-Falle: It's not islam, it's religion...
# ...                                                 ...
# 2950                        Acht Jahre ohne Schwerkraft
# 2951                            Die Neue vom News-Tower
# 2952                                     OLLAS LEIWAUND
# 2953             Ich suchte Gott. Also wurde ich Muslim
# 2954                               Mein verlorener Sohn
#
# [2955 rows x 11 columns]

# %%
# !openai tools fine_tunes.prepare_data -f "../data/output.jsonl"
# Out:
# Analyzing...
#
# - Your file contains 2955 prompt-completion pairs
# - Based on your data it seems like you're trying to fine-tune a model for classification
# - For classification, we recommend you try one of the faster and cheaper models, such as `ada`
# - For classification, you can estimate the expected model performance by keeping a held out dataset, which is not used for training
# - There are 6 duplicated prompt-completion sets. These are rows: [33, 35, 1464, 2350, 2935, 2939]
# - All prompts end with suffix `\n\n###\n\n`
# - All completions start with prefix `Article is similar to the given one: `. Most of the time you should only add the output data into the completion, without any prefix
# - The completion should start with a whitespace character (` `). This tends to produce better results due to the tokenization we use. See https://platform.openai.com/docs/guides/fine-tuning/preparing-your-dataset for more details
#
# Based on the analysis we will perform the following actions:
# - [Recommended] Remove 6 duplicate rows [Y/n]: ^C

# %%
openai.api_key = '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'
response = openai.File.create(
  file=open("output.jsonl", "rb"),
  purpose='fine-tune'
)

# %%
training_file_id = response['id']
training_file_id
# Out:
# 'file-xVTl8oT68dtyIQoIoIelHDT9'

# %%
# !curl -H "Authorization: Bearer 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" "https://api.openai.com/v1/usage?date=2023-07-04"
# Out:
# {
#   "object": "list",
#   "data": [],
#   "ft_data": [],
#   "dalle_api_data": [],
#   "whisper_api_data": [],
#   "current_usage_usd": 0.0
# }

# %%
create_args = {
	"training_file": "file-xVTl8oT68dtyIQoIoIelHDT9",
	"model": "ada",
	"n_epochs": 30,
	"batch_size": 15,
	"learning_rate_multiplier": 0.3
}

response = openai.FineTune.create(**create_args)
job_id = response["id"]
status = response["status"]

print(f'Fine-tunning model with jobID: {job_id}.')
print(f"Training Response: {response}")
print(f"Training Status: {status}")
# Out:
# Fine-tunning model with jobID: ft-2zDtAsjWVkcDi3Y9BOPIr26b.
# Training Response: {
#   "object": "fine-tune",
#   "id": "ft-2zDtAsjWVkcDi3Y9BOPIr26b",
#   "hyperparams": {
#     "n_epochs": 30,
#     "batch_size": 15,
#     "prompt_loss_weight": 0.01,
#     "learning_rate_multiplier": 0.3
#   },
#   "organization_id": "org-7uMAe43mjF7WfaPGibZ4WDao",
#   "model": "ada",
#   "training_files": [
#     {
#       "object": "file",
#       "id": "file-xVTl8oT68dtyIQoIoIelHDT9",
#       "purpose": "fine-tune",
#       "filename": "file",
#       "bytes": 2545916,
#       "created_at": 1688488939,
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "validation_files": [],
#   "result_files": [],
#   "created_at": 1688556417,
#   "updated_at": 1688556417,
#   "status": "pending",
#   "fine_tuned_model": null,
#   "events": [
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Created fine-tune: ft-2zDtAsjWVkcDi3Y9BOPIr26b",
#       "created_at": 1688556417
#     }
#   ]
# }
# Training Status: pending

# %%
fine_tuned_model = response.fine_tuned_model

# %%
fine_tuned_model

# %%
openai.api_key = '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'
openai.FineTune.list()
# Out:
# <OpenAIObject list at 0x7f7b605603b0> JSON: {
#   "object": "list",
#   "data": [
#     {
#       "object": "fine-tune",
#       "id": "ft-oaMFGT8PebjlkghZYZ9a1CcM",
#       "hyperparams": {
#         "n_epochs": 15,
#         "batch_size": 3,
#         "prompt_loss_weight": 0.01,
#         "learning_rate_multiplier": 0.3
#       },
#       "organization_id": "org-7uMAe43mjF7WfaPGibZ4WDao",
#       "model": "ada",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-xVTl8oT68dtyIQoIoIelHDT9",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 2545916,
#           "created_at": 1688488939,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-KHSQZNFUYt4xhjF1UDSva32e",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 911068,
#           "created_at": 1688567313,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1688550231,
#       "updated_at": 1688567314,
#       "status": "succeeded",
#       "fine_tuned_model": "ada:ft-became-ai-2023-07-05-14-28-32"
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-2zDtAsjWVkcDi3Y9BOPIr26b",
#       "hyperparams": {
#         "n_epochs": 30,
#         "batch_size": 15,
#         "prompt_loss_weight": 0.01,
#         "learning_rate_multiplier": 0.3
#       },
#       "organization_id": "org-7uMAe43mjF7WfaPGibZ4WDao",
#       "model": "ada",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-xVTl8oT68dtyIQoIoIelHDT9",
#           "purpose": "fine-tune",
#           "filename": "file",
#           "bytes": 2545916,
#           "created_at": 1688488939,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [],
#       "result_files": [],
#       "created_at": 1688556417,
#       "updated_at": 1688561000,
#       "status": "cancelled",
#       "fine_tuned_model": null
#     }
#   ]
# }

# %%
fine_tuned_model = openai.FineTune.retrieve(id="ft-oaMFGT8PebjlkghZYZ9a1CcM").fine_tuned_model

# %%
openai.FineTune.list_events(id="ft-oaMFGT8PebjlkghZYZ9a1CcM")
# Out:
# <OpenAIObject list at 0x7f7b3c33b970> JSON: {
#   "object": "list",
#   "data": [
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Created fine-tune: ft-oaMFGT8PebjlkghZYZ9a1CcM",
#       "created_at": 1688550231
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune costs $5.04",
#       "created_at": 1688556769
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune enqueued. Queue number: 21",
#       "created_at": 1688556770
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 20",
#       "created_at": 1688558952
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 19",
#       "created_at": 1688558997
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 18",
#       "created_at": 1688559311
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 17",
#       "created_at": 1688559332
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 16",
#       "created_at": 1688559366
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 15",
#       "created_at": 1688560039
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 14",
#       "created_at": 1688560186
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 13",
#       "created_at": 1688560226
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 12",
#       "created_at": 1688560231
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 11",
#       "created_at": 1688560234
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 10",
#       "created_at": 1688560281
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 9",
#       "created_at": 1688560326
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 8",
#       "created_at": 1688560357
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 7",
#       "created_at": 1688560396
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 6",
#       "created_at": 1688560806
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 5",
#       "created_at": 1688561553
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 4",
#       "created_at": 1688561667
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 3",
#       "created_at": 1688561732
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 2",
#       "created_at": 1688561741
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 1",
#       "created_at": 1688561785
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 0",
#       "created_at": 1688561841
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune started",
#       "created_at": 1688561908
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Completed epoch 1/15",
#       "created_at": 1688562281
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Completed epoch 3/15",
#       "created_at": 1688562992
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Completed epoch 5/15",
#       "created_at": 1688563709
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Completed epoch 7/15",
#       "created_at": 1688564423
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Completed epoch 9/15",
#       "created_at": 1688565140
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Completed epoch 11/15",
#       "created_at": 1688565858
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Completed epoch 13/15",
#       "created_at": 1688566575
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Completed epoch 15/15",
#       "created_at": 1688567290
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Uploaded model: ada:ft-became-ai-2023-07-05-14-28-32",
#       "created_at": 1688567312
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Uploaded result file: file-KHSQZNFUYt4xhjF1UDSva32e",
#       "created_at": 1688567314
#     },
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Fine-tune succeeded",
#       "created_at": 1688567314
#     }
#   ]
# }

# %%
openai.api_key = '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'
answer = openai.Completion.create(
    model="ada:ft-became-ai-2023-07-05-14-28-32", 
    max_tokens=20,
    temperature=0.2,
    prompt="medienjahr bilanzieren attentat charlie hebdo begann mitteilung endet wahlsieg britischen konservativen deren finanzminister gleich zweimal skrupellosen medienmogul rupert murdoch getroffen ehe minister ffentlich-rechtlichen bbc direkten konkurrenten murdochs saftige krzungen auferlegte verlust 1000 arbeitspltzen schlieung sendern fhren medienjahr sagen meldung facebook-grnders mark zuckerberg 99 prozent teil steuervermeidung angehuften vermgens gesmbh umlagern gutes tun weltweit groe karitative tat gefeiert wurde medienjahr sagen ton sozialen medien morddrohungen antisemitischen beschimpfungen falter-redakteure aufschaukelte ber medienjahr sagen freiheit presse fen getreten wurde zuletzt staaten titel mitteleuropa wenigen jahren eu demokratische hoffnungstrger gehtschelt worden medienjahr sagen social-media-konzerne multis weiterhin erfolgreich vermeiden eu steuern zahlen jahr luxleaks auffliegen luxemburg-connections denen fhrung damaligen premierministers jean-claude juncker luxemburg assistent steuervermeider google apple amazon figurierte wurden nachzahlungsstrafen ber paar beltter verhngt geschah wenig europische parlament bemht eu sorgen europische netzwerk eurodad engagiert kampf fr steuergerechtigkeit konstatiert steuervermeidung fr multis heute genauso wenig problem jahr juncker inzwischen eu-kommissionsprsident bedauert gewiss niemand sagen umsatz facebook co sterreich steuer bezahlen mssten bezahlen fast egal sterreichische medienminister lieber kunst beschftigt medienpolitik medienfrderung wei machtfrage dabei gewinnen mchtigen strkt gelang beschluss medientransparenzgesetzes zementiert qualitt kriterium frdernden medien darstellt einzig deren reichweite medienpolitik folgt vorbild agrarpolitik qualitt gefrdert grobauer teufel hufchen hingelegt scheit politik geld steuerzahler drauf sozusagen gutes jahr fr medien facebook schloss vertrge springer spiegel guardian new york times vermarktung einzelnen artikeln instant articles heit unternehmen arbeitsteilung vielversprechend verkaufen verlage inserate drfen geld behalten kassiert facebook 30 prozent klingt gut ntzt facebook publizistischen medien fragmentiert mehr einzelne artikel gehandelt wozu ganze medien publizieren verlag trend entziehen falter verlag erkennt eigenen auflsung beitrgt usa fhren kolonisierenden handelskrieg europa hiesigen verlage politik eliten spielen mehr weniger begeistert geht ums groe geschft geht macht hegemonie diskurs lage wirkt schon bizarr scheint wre beherrschende")

# %%
answer
# Out:
# <OpenAIObject text_completion id=cmpl-7ZLxVayioHm8WvFs5hUB5VhHkKDEv at 0x7feab12296c0> JSON: {
#   "id": "cmpl-7ZLxVayioHm8WvFs5hUB5VhHkKDEv",
#   "object": "text_completion",
#   "created": 1688660245,
#   "model": "ada:ft-became-ai-2023-07-05-14-28-32",
#   "choices": [
#     {
#       "text": "\n\n\n###\n\nArticle is similar to the given one: \"Wir h\u00e4tten uns",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "length"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 884,
#     "completion_tokens": 20,
#     "total_tokens": 904
#   }
# }

# %%
joined.head(1).paragraphs.values
# Out:
# array(['[\'Also, wie soll man ein Medienjahr bilanzieren, das mit dem Attentat auf Charlie Hebdo begann und mit der Mitteilung endet, nach dem Wahlsieg der britischen Konservativen habe deren Finanzminister gleich zweimal den skrupellosen Medienmogul Rupert Murdoch getroffen? Und zwar ehe der Minister der öffentlich-rechtlichen BBC, dem direkten Konkurrenten Murdochs, saftige Kürzungen auferlegte, die zum Verlust von 1000 Arbeitsplätzen und zur Schließung von Sendern führen werden.\', \'Was soll man zu einem Medienjahr sagen, in dem die Meldung des Facebook-Gründers Mark Zuckerberg, er werde 99 Prozent seines zum Teil durch Steuervermeidung angehäuften Vermögens in eine Ges.m.b.H. umlagern, die Gutes tun wird oder so, weltweit als große karitative Tat gefeiert wurde?\', \'Was soll man zu einem Medienjahr sagen, in dem sich der Ton in den sozialen Medien bis zu Morddrohungen und antisemitischen Beschimpfungen, auch gegen Falter-Redakteure, aufschaukelte?\', \'Was soll man über ein Medienjahr sagen, in dem die Freiheit der Presse mit Füßen getreten wurde, nicht zuletzt auch in jenen Staaten, die unter dem Titel "Mitteleuropa" vor wenigen Jahren von der EU noch als demokratische Hoffnungsträger gehätschelt worden waren?\', \'Was soll man zu einem Medienjahr sagen, in dem die Social-Media-Konzerne und andere Multis es weiterhin erfolgreich vermeiden, in der EU und sonst wo Steuern zu zahlen? Ein Jahr nach Luxleaks, dem Auffliegen der Luxemburg-Connections, bei denen unter Führung des damaligen Premierministers Jean-Claude Juncker Luxemburg als Assistent der Steuervermeider von Google, Apple, Amazon und so weiter figurierte, wurden Nachzahlungsstrafen über ein paar Übeltäter verhängt. Weiter geschah wenig. Das Europäische Parlament bemüht sich, die EU hat andere Sorgen. Das europäische Netzwerk Eurodad, engagiert im Kampf für Steuergerechtigkeit, konstatiert, dass Steuervermeidung für Multis heute genauso wenig ein Problem ist wie vor einem Jahr. Juncker, inzwischen EU-Kommissionspräsident, bedauert gewiss sehr.\', \'Niemand kann sagen, wie viel Umsatz Facebook und Co in Österreich machen, wie viel Steuer sie bezahlen müssten und wie viel sie bezahlen. Da ist es fast egal, dass der österreichische Medienminister sich lieber mit der Kunst beschäftigt als mit Medienpolitik. Medienförderung, das weiß er, ist eine Machtfrage, dabei kann er nur gewinnen, wenn er die Mächtigen weiter stärkt. Das gelang mit dem Beschluss des Medientransparenzgesetzes. Dieses zementiert, dass nicht Qualität das Kriterium der zu fördernden Medien darstellt, sondern einzig deren Reichweite. Medienpolitik folgt dem Vorbild der Agrarpolitik: Nicht Qualität wird gefördert, sondern der Großbauer. Wo der Teufel sein Häufchen hingelegt hat, dort scheißt die Politik mit dem Geld der Steuerzahler drauf, sozusagen.\', \'Es war kein gutes Jahr für die Medien. Facebook schloss Verträge mit Springer, dem Spiegel, dem Guardian und der New York Times zur Vermarktung von einzelnen Artikeln. "Instant Articles" heißt das Unternehmen, und die Arbeitsteilung ist vielversprechend. Verkaufen die Verlage Inserate, dürfen sie das Geld behalten. Sonst kassiert Facebook 30 Prozent. Klingt gut, nützt nur Facebook. Weil es die publizistischen Medien fragmentiert. Wenn nur mehr einzelne Artikel gehandelt werden, wozu dann noch ganze Medien publizieren? Kein Verlag kann sich diesem Trend entziehen (auch der Falter Verlag nicht), selbst wenn er erkennt, dass er zu seiner eigenen Auflösung beiträgt.\', \'Die USA führen einen kolonisierenden Handelskrieg gegen Europa, die hiesigen Verlage, die Politik und die Eliten spielen mehr oder weniger begeistert mit. Es geht ums große Geschäft. Es geht um Macht, um die Hegemonie im Diskurs. In dieser Lage wirkt es schon etwas bizarr, wenn es scheint, als wäre das beherrschende Thema jenes der Lügenpresse geworden, unterbrochen von weinerlichen Selbstbezichtigungen liberaler Publizistinnen und Publizisten, man glaube ihnen nicht mehr.\', \'Was erwart ...
#       dtype=object)

# %%
demo[demo.title.str.contains("Wir sind die ne")].paragraphs.values
# Out:
# array(['[\'Es ist zwar erst zehn Uhr Vormittag, aber Maurice Ernst hat schon einen ausgiebigen Spaziergang durch das winterliche Wien hinter sich. Er ist ganz in Schwarz gekleidet, seine Haare sind grellblond gefärbt, die Augen leuchten blaugrün. Am Handgelenk baumelt ein Goldketterl, im linken Ohrläppchen glänzt ein Sportwagen-Flinserl. Der 26-Jährige ist ausnehmend höflich und eindrucksvoll mitteilsam. Er spricht fast ohne Punkt und Komma, seine Hände sprechen mit, und gerne unterstreicht er Aussagen mit der Phrase "Punkt, Ende, aus".\', \'Seine Band Bilderbuch hat er vor zehn Jahren als Klosterschüler in Kremsmünster gegründet. Zwei Alben zwischen deutschsprachigem Indiepop und ambitioniertem Denkerrock brachten Achtungserfolge, zwei Singles 2013 die stilistische Neuerfindung und den Durchbruch: "Plansch" und "Maschin" wurden weit über die lokale Indie-Szene hinaus zu Hits, die Bilderbuch die deutschen Festivalbühnen öffneten; das Feuilleton reagierte euphorisch.\', \'"Diese Musik ist geil, weil sie geil ist", schrieb die Süddeutsche Zeitung, und genauso verhält es sich auch mit dem Album "Schick Schock", das am 20.2. auf dem bandeigenen Label Maschin Records erscheint: Maurice Ernst lässt dem Falco in sich freien Lauf, und Bilderbuch geben dem österreichischen Pop, was ihm so lange fehlte: eine ordentliche Portion Sexappeal.\', \'Falter: Herr Ernst, wann läutet denn Ihr Wecker?\', \'Maurice Ernst: Heute war er auf zehn vor acht gestellt, aber ich bin schon davor aufgewacht. Wir müssen die Tage bis zum Erscheinen des Albums gerade echt nutzen. Wenn man ein eigenes Label hat und als Band überall die Finger im Spiel haben will, muss man viel Zeit und Disziplin aufwenden. Weil einfach jedes Detail wichtig ist.\', \'Sie sind also nicht nur Künstler, sondern auch verantwortlicher Unternehmer?\', \'Ernst: "Unternehmer" trifft es nicht wirklich, aber zum Künstlerdasein gehört mittlerweile mehr dazu als nur die Kunst. Du musst Verantwortung übernehmen, um dorthin zu kommen, wo du hinwillst. "Ich bin Musiker, und hinter mir die Sintflut", so läuft es nicht mehr. Natürlich geht es phasenweise nur um Musik, aber dann geht es ums Artwork, die Live-Umsetzung, die Konzeption von Videos und so weiter. Ich bin schlecht darin, Dinge aus der Hand zu geben, weil ich fast niemandem wirklich vertraue.\', \'Mehr Erfolg heißt also auch mehr Verantwortung und mehr Belastung?\', \'Ernst: Man passt sich an eine neue Situation an und versucht, Quantität und Qualität in eine Balance zu bringen, ohne seine Prinzipien zu verraten. Plötzlich geht alles schneller. Wir kommen jetzt etwa auf den Bravo-Hits-Sampler. Früher hätte ich mich eine Woche lang drüber gefreut, weil ich den als Kind immer gehört habe. Jetzt ist das nur ein schnelles Mail, und man ist im Kopf schon wieder woanders.\', \'Die Alternative-Band auf der Teeniepop-CD, wie passt das?\', \'Ernst: Als wir mit "Maschin" bei "Willkommen Österreich" waren, haben uns Stermann/Grissemann gefragt, wie sie uns ansagen sollen. In diesem Moment war es eine ganz bewusste Entscheidung, "als Popband" zu sagen. Durchaus auch aus Trotz, denn ich hatte dieses ewige "Die nächste Indie-Band aus Österreich"-Blabla satt. Unsere Musik ist größer als dieses Indie-Ding und dieses kleinkarierte österreichische Denken, dachte ich mir. Wir stellen uns über das System!\', \'Das System "Alternative Pop" oder das System "österreichische Szene"?\', \'Ernst: Beides. Genremäßig haben wir uns mehr Freiheiten genommen, weil uns klar wurde, dass wir keine Grenzen haben. Pop bringt Musik auf den Zeitgeist, er kann sich an Klischees sämtlicher Richtungen bedienen. Es geht nicht nur um den Sound, sondern auch um die Attitüde dahinter und darum, wie man die Musikgeschichte für seine eigene Musik verwendet. Der US-Rapper Kanye West war da ein wichtiger Einfluss. Er hat seinen Hip-Hop mit Elementen europäischer Musik collagiert, und wir dachten uns: Hey, das können wir andersrum ja auch probieren! Genau das haben wir mit Songs wie " ...
#       dtype=object)

# %%
def get_category(text):
    answer = openai.Completion.create(
    model="ada:ft-became-ai-2023-07-05-14-28-32",
    prompt=text)

    print(answer['choices'][0]['text'])

# %%
joined[joined["article_id"] == "FALTER_201512234A05C075C5"].paragraphs[0]
# Out:
# '[\'Also, wie soll man ein Medienjahr bilanzieren, das mit dem Attentat auf Charlie Hebdo begann und mit der Mitteilung endet, nach dem Wahlsieg der britischen Konservativen habe deren Finanzminister gleich zweimal den skrupellosen Medienmogul Rupert Murdoch getroffen? Und zwar ehe der Minister der öffentlich-rechtlichen BBC, dem direkten Konkurrenten Murdochs, saftige Kürzungen auferlegte, die zum Verlust von 1000 Arbeitsplätzen und zur Schließung von Sendern führen werden.\', \'Was soll man zu einem Medienjahr sagen, in dem die Meldung des Facebook-Gründers Mark Zuckerberg, er werde 99 Prozent seines zum Teil durch Steuervermeidung angehäuften Vermögens in eine Ges.m.b.H. umlagern, die Gutes tun wird oder so, weltweit als große karitative Tat gefeiert wurde?\', \'Was soll man zu einem Medienjahr sagen, in dem sich der Ton in den sozialen Medien bis zu Morddrohungen und antisemitischen Beschimpfungen, auch gegen Falter-Redakteure, aufschaukelte?\', \'Was soll man über ein Medienjahr sagen, in dem die Freiheit der Presse mit Füßen getreten wurde, nicht zuletzt auch in jenen Staaten, die unter dem Titel "Mitteleuropa" vor wenigen Jahren von der EU noch als demokratische Hoffnungsträger gehätschelt worden waren?\', \'Was soll man zu einem Medienjahr sagen, in dem die Social-Media-Konzerne und andere Multis es weiterhin erfolgreich vermeiden, in der EU und sonst wo Steuern zu zahlen? Ein Jahr nach Luxleaks, dem Auffliegen der Luxemburg-Connections, bei denen unter Führung des damaligen Premierministers Jean-Claude Juncker Luxemburg als Assistent der Steuervermeider von Google, Apple, Amazon und so weiter figurierte, wurden Nachzahlungsstrafen über ein paar Übeltäter verhängt. Weiter geschah wenig. Das Europäische Parlament bemüht sich, die EU hat andere Sorgen. Das europäische Netzwerk Eurodad, engagiert im Kampf für Steuergerechtigkeit, konstatiert, dass Steuervermeidung für Multis heute genauso wenig ein Problem ist wie vor einem Jahr. Juncker, inzwischen EU-Kommissionspräsident, bedauert gewiss sehr.\', \'Niemand kann sagen, wie viel Umsatz Facebook und Co in Österreich machen, wie viel Steuer sie bezahlen müssten und wie viel sie bezahlen. Da ist es fast egal, dass der österreichische Medienminister sich lieber mit der Kunst beschäftigt als mit Medienpolitik. Medienförderung, das weiß er, ist eine Machtfrage, dabei kann er nur gewinnen, wenn er die Mächtigen weiter stärkt. Das gelang mit dem Beschluss des Medientransparenzgesetzes. Dieses zementiert, dass nicht Qualität das Kriterium der zu fördernden Medien darstellt, sondern einzig deren Reichweite. Medienpolitik folgt dem Vorbild der Agrarpolitik: Nicht Qualität wird gefördert, sondern der Großbauer. Wo der Teufel sein Häufchen hingelegt hat, dort scheißt die Politik mit dem Geld der Steuerzahler drauf, sozusagen.\', \'Es war kein gutes Jahr für die Medien. Facebook schloss Verträge mit Springer, dem Spiegel, dem Guardian und der New York Times zur Vermarktung von einzelnen Artikeln. "Instant Articles" heißt das Unternehmen, und die Arbeitsteilung ist vielversprechend. Verkaufen die Verlage Inserate, dürfen sie das Geld behalten. Sonst kassiert Facebook 30 Prozent. Klingt gut, nützt nur Facebook. Weil es die publizistischen Medien fragmentiert. Wenn nur mehr einzelne Artikel gehandelt werden, wozu dann noch ganze Medien publizieren? Kein Verlag kann sich diesem Trend entziehen (auch der Falter Verlag nicht), selbst wenn er erkennt, dass er zu seiner eigenen Auflösung beiträgt.\', \'Die USA führen einen kolonisierenden Handelskrieg gegen Europa, die hiesigen Verlage, die Politik und die Eliten spielen mehr oder weniger begeistert mit. Es geht ums große Geschäft. Es geht um Macht, um die Hegemonie im Diskurs. In dieser Lage wirkt es schon etwas bizarr, wenn es scheint, als wäre das beherrschende Thema jenes der Lügenpresse geworden, unterbrochen von weinerlichen Selbstbezichtigungen liberaler Publizistinnen und Publizisten, man glaube ihnen nicht mehr.\', \'Was erwarte ich m ...

# %%
# !curl -H "Authorization: Bearer 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" "https://api.openai.com/v1/usage?date=2023-07-06"
# Out:
# {
#   "object": "list",
#   "data": [
#     {
#       "aggregation_timestamp": 1688658000,
#       "n_requests": 1,
#       "operation": "completion",
#       "snapshot_id": "ada:ft-became-ai-2023-07-05-14-28-32",
#       "n_context": 1,
#       "n_context_tokens_total": 870,
#       "n_generated": 1,
#       "n_generated_tokens_total": 20
#     },
#     {
#       "aggregation_timestamp": 1688658900,
#       "n_requests": 3,
#       "operation": "completion",
#       "snapshot_id": "ada:ft-became-ai-2023-07-05-14-28-32",
#       "n_context": 3,
#       "n_context_tokens_total": 2625,
#       "n_generated": 3,
#       "n_generated_tokens_total": 60
#     }
#   ],
#   "ft_data": [],
#   "dalle_api_data": [],
#   "whisper_api_data": [],
#   "current_usage_usd": 0.0
# }
